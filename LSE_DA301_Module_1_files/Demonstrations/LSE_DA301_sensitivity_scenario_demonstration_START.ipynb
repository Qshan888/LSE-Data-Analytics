# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 301: Advanced Analytics for Organisational Impact

# %% [markdown]
# ## Demonstration: Sensitivity scenario and what-if analysis combined

# %% [markdown]
# You’ve created a retirement model for the wealth management company and plotted the results in a DataFrame, let’s see how the model responds to different outputs and scenarios to solve a specific business challenge. In this demonstration, we will combine a sensitivity scenario and a what-if analysis.

# %% [markdown]
# #

# %% [markdown]
# # Sensitivity scenario

# %% [markdown]
# ## Prepare your workstation

# %% [markdown]
# > The code snippets and data are based on the previous model.

# %% [markdown]
# ### Import the necessary libraries.

# %%
# Define classes to contain and encapsulate data.
from dataclasses import dataclass 
import pandas as pd
# Import in-built module for generating random numbers. 
import random 
# Display output inline.
# %matplotlib inline
# Import to replicate a nested loop over the input values.
from sensitivity import SensitivityAnalyzer 

# Import warnings and disable.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Specify the inputs

# %%
# Create a DataFrame consisting of various classes using Python's 'dataclass()'
# module and Object Oriented Programming (OPP).
@dataclass

class ModelInputs: 
    # Define the class and specify the default inputs. 
    starting_salary: int = 30000
    promos_every_n_years: int = 3
    cost_of_living_raise: float = 0.025
    promo_raise: float = 0.15
    savings_rate: float = 0.20
    interest_rate: float = 0.07
    desired_cash: int = 1000000

# Create an instance of the new class with the default inputs.
model_data = ModelInputs() 

# Print the results.
model_data
# Out:
# ModelInputs(starting_salary=30000, promos_every_n_years=3, cost_of_living_raise=0.025, promo_raise=0.15, savings_rate=0.2, interest_rate=0.07, desired_cash=1000000)

# %% [markdown]
# ### Calculate wage

# %%
# Get the wage at a given year from the start of the model based 
# on the cost of living raises and regular promotions.
def wages_year(data: ModelInputs, year):
    # Every n years we have a promotion, so dividing the years and
    # taking out the decimals gets the number of promotions.
    num_promos = int(year / data.promos_every_n_years)  
    
   # This is the formula above implemented in Python.
    salary_t = data.starting_salary * (1 + data.cost_of_living_raise)\
    ** year * (1 + data.promo_raise) ** num_promos
    return salary_t

# Show the first four salaries in the range and 
# print the results using the f-string.
for i in range(4):
    year = i + 1
    salary = wages_year(model_data, year)
    print(f'The wage at year {year} is £{salary:,.0f}.')
# Out:
# The wage at year 1 is £30,750.
# The wage at year 2 is £31,519.
# The wage at year 3 is £37,153.
# The wage at year 4 is £38,082.

# %% [markdown]
# ### Calculate wealth

# %%
# Calculate the cash saved within a given year by first 
# calculating the salary at that year then applying the savings rate.
def cash_saved_during_year(data: ModelInputs, year):
    salary = wages_year(data, year)
    cash_saved = salary * data.savings_rate
    return cash_saved

# Calculate the accumulated wealth for a given year based
# on previous wealth, the investment rate, and cash saved during the year.
def wealth_year(data: ModelInputs, year, prior_wealth):
                cash_saved = cash_saved_during_year(data, year)
                wealth = prior_wealth * (1 + data.interest_rate) + cash_saved
                return wealth

# Start with no cash saved.
prior_wealth = 0  
for i in range(4):
    year = i + 1
    wealth = wealth_year(model_data, year, prior_wealth)
    print(f'The wealth at year {year} is £{wealth:,.0f}.')
    
    # Set next year's prior wealth to this year's wealth:
    prior_wealth = wealth
# Out:
# The wealth at year 1 is £6,150.
# The wealth at year 2 is £12,884.
# The wealth at year 3 is £21,217.
# The wealth at year 4 is £30,318.

# %% [markdown]
# ### Calculate years to retirement

# %%
def years_to_retirement(data: ModelInputs, print_output=True):
    # Start with no cash saved.
    prior_wealth = 0  
    wealth = 0
    # The ‘year’ becomes ‘1’ on the first loop.
    year = 0  
   
    if print_output:
        print('Wealth over time:')
    while wealth < data.desired_cash:
        year = year + 1
        wealth = wealth_year(data, year, prior_wealth)
        if print_output:
            print(f'The accumulated wealth at year {year} is £{wealth:,.0f}.')
            # Set next year's prior wealth to this year's wealth.
        prior_wealth = wealth  
       
    # Now we have run the while loop, the wealth must be >= desired_cash 
    # (whatever last year was set is the years to retirement), which we can print.
    if print_output:
        # \n makes a blank line in the output.
        print(f'\nRetirement:\nIt will take {year} years to retire.')  
    return year

years_to_retirement(model_data)
# Out:
# Wealth over time:
# The accumulated wealth at year 1 is £6,150.
# The accumulated wealth at year 2 is £12,884.
# The accumulated wealth at year 3 is £21,217.
# The accumulated wealth at year 4 is £30,318.
# The accumulated wealth at year 5 is £40,247.
# The accumulated wealth at year 6 is £52,267.
# The accumulated wealth at year 7 is £65,358.
# The accumulated wealth at year 8 is £79,601.
# The accumulated wealth at year 9 is £96,569.
# The accumulated wealth at year 10 is £115,010.
# The accumulated wealth at year 11 is £135,033.
# The accumulated wealth at year 12 is £158,599.
# The accumulated wealth at year 13 is £184,167.
# The accumulated wealth at year 14 is £211,887.
# The accumulated wealth at year 15 is £244,197.
# The accumulated wealth at year 16 is £279,206.
# The accumulated wealth at year 17 is £317,114.
# The accumulated wealth at year 18 is £360,957.
# The accumulated wealth at year 19 is £408,411.
# The accumulated wealth at year 20 is £459,741.
# The accumulated wealth at year 21 is £518,729.
# The accumulated wealth at year 22 is £582,517.
# The accumulated wealth at year 23 is £651,456.
# The accumulated wealth at year 24 is £730,256.
# The accumulated wealth at year 25 is £815,401.
# The accumulated wealth at year 26 is £907,357.
# The accumulated wealth at year 27 is £1,011,985.
#
# Retirement:
# It will take 27 years to retire.
# 27

# %% [markdown]
# #

# %% [markdown]
# ## 1. Defining functions for calculating the values for sensitivity analysis

# %%
# Define the function that accepts the individual parameters.
# Note parameters are pecified sparatel.
def years_to_retirement_separate_args(
    # List the parameters and set their values.
    starting_salary=20000, 
    promos_every_n_years=5, 
    cost_of_living_raise=0.02,
    promo_raise= 0.15, 
    savings_rate=0.25, 
    interest_rate=0.05, 
    desired_cash=1000000): 
 
    # Update the values of the parameters:
    data = ModelInputs(
        starting_salary=starting_salary, 
        promos_every_n_years=promos_every_n_years, 
        cost_of_living_raise=cost_of_living_raise, 
        promo_raise=promo_raise, 
        savings_rate=savings_rate, 
        interest_rate=interest_rate, 
        desired_cash=desired_cash)
       
    return years_to_retirement(data, print_output=False)

# Call the function.
years_to_retirement_separate_args()
# Out:
# 37

# %% [markdown]
# ## 2. Generate random values for the input variables

# %%
# Use Python's 'list comprehensions' syntax to make it easier to adjust the inputs. 
# Use 'i' as a temporary variable to store the value's position in the range:
sensitivity_values = {
    'starting_salary': [i * 10000 for i in range(2, 6)],
    'promos_every_n_years': [i for i in range(2, 6)],
    'cost_of_living_raise': [i/100 for i in range(1, 4)],
    'promo_raise': [i/100 for i in range(10, 25, 5)],
    'savings_rate': [i/100 for i in range(10, 50, 10)],
    'interest_rate': [i/100 for i in range(3, 8)],
    'desired_cash': [i * 100000 for i in range(10, 26, 5)]}

# %% [markdown]
# ## 3. Running the sensitivity analyse module

# %%
# Run the Python’s SensitivityAnalyzer with the all the assigned inputs:
sa = SensitivityAnalyzer(
    sensitivity_values,
    years_to_retirement_separate_args,
    result_name="Years to retirement",
    reverse_colors=True,
    grid_size=3)
# Out:
# 100%|███████████████████████████████████| 11520/11520 [00:04<00:00, 2824.10it/s]

# %% [markdown]
# ## 4. Display the results

# %%
# Display the results using a DataFrame.
styled_dict = sa.styled_dfs(num_fmt='{:.1f}')
# Out:
# <h2>Years to retirement by starting_salary vs. promos_every_n_years</h2>
# <style type="text/css">
# #T_11615_row0_col0 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_11615_row0_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_11615_row0_col2 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_11615_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_11615_row1_col0 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_11615_row1_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_11615_row1_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_11615_row1_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_11615_row2_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_11615_row2_col1 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_11615_row2_col2 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_11615_row2_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_11615_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_11615_row3_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_11615_row3_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_11615_row3_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# </style>
# <table id="T_11615">
#   <caption>Years to retirement - starting_salary vs. promos_every_n_years</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11615_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_11615_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_11615_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_11615_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11615_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_11615_row0_col0" class="data row0 col0" >35.0</td>
#       <td id="T_11615_row0_col1" class="data row0 col1" >40.6</td>
#       <td id="T_11615_row0_col2" class="data row0 col2" >44.0</td>
#       <td id="T_11615_row0_col3" class="data row0 col3" >46.3</td>
#     </tr>
#     <tr>
#       <th id="T_11615_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_11615_row1_col0" class="data row1 col0" >31.0</td>
#       <td id="T_11615_row1_col1" class="data row1 col1" >35.8</td>
#       <td id="T_11615_row1_col2" class="data row1 col2" >38.7</td>
#       <td id="T_11615_row1_col3" class="data row1 col3" >40.6</td>
#     </tr>
#     <tr>
#       <th id="T_11615_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_11615_row2_col0" class="data row2 col0" >28.3</td>
#       <td id="T_11615_row2_col1" class="data row2 col1" >32.5</td>
#       <td id="T_11615_row2_col2" class="data row2 col2" >35.1</td>
#       <td id="T_11615_row2_col3" class="data row2 col3" >36.8</td>
#     </tr>
#     <tr>
#       <th id="T_11615_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_11615_row3_col0" class="data row3 col0" >26.3</td>
#       <td id="T_11615_row3_col1" class="data row3 col1" >30.1</td>
#       <td id="T_11615_row3_col2" class="data row3 col2" >32.4</td>
#       <td id="T_11615_row3_col3" class="data row3 col3" >33.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by starting_salary vs. cost_of_living_raise</h2>
# <style type="text/css">
# #T_1a2d6_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1a2d6_row0_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_1a2d6_row0_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_1a2d6_row1_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_1a2d6_row1_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_1a2d6_row1_col2 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_1a2d6_row2_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_1a2d6_row2_col1 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_1a2d6_row2_col2 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_1a2d6_row3_col0 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_1a2d6_row3_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_1a2d6_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a2d6">
#   <caption>Years to retirement - starting_salary vs. cost_of_living_raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a2d6_level0_col0" class="col_heading level0 col0" >0.010000</th>
#       <th id="T_1a2d6_level0_col1" class="col_heading level0 col1" >0.020000</th>
#       <th id="T_1a2d6_level0_col2" class="col_heading level0 col2" >0.030000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a2d6_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_1a2d6_row0_col0" class="data row0 col0" >44.4</td>
#       <td id="T_1a2d6_row0_col1" class="data row0 col1" >41.3</td>
#       <td id="T_1a2d6_row0_col2" class="data row0 col2" >38.7</td>
#     </tr>
#     <tr>
#       <th id="T_1a2d6_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_1a2d6_row1_col0" class="data row1 col0" >39.0</td>
#       <td id="T_1a2d6_row1_col1" class="data row1 col1" >36.4</td>
#       <td id="T_1a2d6_row1_col2" class="data row1 col2" >34.2</td>
#     </tr>
#     <tr>
#       <th id="T_1a2d6_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_1a2d6_row2_col0" class="data row2 col0" >35.3</td>
#       <td id="T_1a2d6_row2_col1" class="data row2 col1" >33.1</td>
#       <td id="T_1a2d6_row2_col2" class="data row2 col2" >31.1</td>
#     </tr>
#     <tr>
#       <th id="T_1a2d6_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_1a2d6_row3_col0" class="data row3 col0" >32.6</td>
#       <td id="T_1a2d6_row3_col1" class="data row3 col1" >30.6</td>
#       <td id="T_1a2d6_row3_col2" class="data row3 col2" >28.8</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by starting_salary vs. promo_raise</h2>
# <style type="text/css">
# #T_6b4af_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6b4af_row0_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_6b4af_row0_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_6b4af_row1_col0 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_6b4af_row1_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_6b4af_row1_col2 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_6b4af_row2_col0 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_6b4af_row2_col1 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_6b4af_row2_col2 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_6b4af_row3_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_6b4af_row3_col1 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_6b4af_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b4af">
#   <caption>Years to retirement - starting_salary vs. promo_raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b4af_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_6b4af_level0_col1" class="col_heading level0 col1" >0.150000</th>
#       <th id="T_6b4af_level0_col2" class="col_heading level0 col2" >0.200000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b4af_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_6b4af_row0_col0" class="data row0 col0" >45.2</td>
#       <td id="T_6b4af_row0_col1" class="data row0 col1" >41.2</td>
#       <td id="T_6b4af_row0_col2" class="data row0 col2" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b4af_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_6b4af_row1_col0" class="data row1 col0" >39.7</td>
#       <td id="T_6b4af_row1_col1" class="data row1 col1" >36.3</td>
#       <td id="T_6b4af_row1_col2" class="data row1 col2" >33.6</td>
#     </tr>
#     <tr>
#       <th id="T_6b4af_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_6b4af_row2_col0" class="data row2 col0" >35.9</td>
#       <td id="T_6b4af_row2_col1" class="data row2 col1" >33.0</td>
#       <td id="T_6b4af_row2_col2" class="data row2 col2" >30.6</td>
#     </tr>
#     <tr>
#       <th id="T_6b4af_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_6b4af_row3_col0" class="data row3 col0" >33.1</td>
#       <td id="T_6b4af_row3_col1" class="data row3 col1" >30.5</td>
#       <td id="T_6b4af_row3_col2" class="data row3 col2" >28.4</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by starting_salary vs. savings_rate</h2>
# <style type="text/css">
# #T_54e93_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_54e93_row0_col1, #T_54e93_row2_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_54e93_row0_col2, #T_54e93_row1_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_54e93_row0_col3, #T_54e93_row2_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_54e93_row1_col0 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_54e93_row1_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_54e93_row1_col3, #T_54e93_row2_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_54e93_row2_col3 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_54e93_row3_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_54e93_row3_col1 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_54e93_row3_col2 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_54e93_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54e93">
#   <caption>Years to retirement - starting_salary vs. savings_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54e93_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_54e93_level0_col1" class="col_heading level0 col1" >0.200000</th>
#       <th id="T_54e93_level0_col2" class="col_heading level0 col2" >0.300000</th>
#       <th id="T_54e93_level0_col3" class="col_heading level0 col3" >0.400000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54e93_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_54e93_row0_col0" class="data row0 col0" >51.5</td>
#       <td id="T_54e93_row0_col1" class="data row0 col1" >42.6</td>
#       <td id="T_54e93_row0_col2" class="data row0 col2" >37.6</td>
#       <td id="T_54e93_row0_col3" class="data row0 col3" >34.2</td>
#     </tr>
#     <tr>
#       <th id="T_54e93_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_54e93_row1_col0" class="data row1 col0" >46.2</td>
#       <td id="T_54e93_row1_col1" class="data row1 col1" >37.6</td>
#       <td id="T_54e93_row1_col2" class="data row1 col2" >32.8</td>
#       <td id="T_54e93_row1_col3" class="data row1 col3" >29.6</td>
#     </tr>
#     <tr>
#       <th id="T_54e93_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_54e93_row2_col0" class="data row2 col0" >42.6</td>
#       <td id="T_54e93_row2_col1" class="data row2 col1" >34.2</td>
#       <td id="T_54e93_row2_col2" class="data row2 col2" >29.6</td>
#       <td id="T_54e93_row2_col3" class="data row2 col3" >26.4</td>
#     </tr>
#     <tr>
#       <th id="T_54e93_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_54e93_row3_col0" class="data row3 col0" >39.8</td>
#       <td id="T_54e93_row3_col1" class="data row3 col1" >31.6</td>
#       <td id="T_54e93_row3_col2" class="data row3 col2" >27.1</td>
#       <td id="T_54e93_row3_col3" class="data row3 col3" >24.1</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by starting_salary vs. interest_rate</h2>
# <style type="text/css">
# #T_57c1a_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_57c1a_row0_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_57c1a_row0_col2 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_57c1a_row0_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_57c1a_row0_col4 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_57c1a_row1_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_57c1a_row1_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_57c1a_row1_col2 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_57c1a_row1_col3 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_57c1a_row1_col4 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_57c1a_row2_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_57c1a_row2_col1 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_57c1a_row2_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_57c1a_row2_col3 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_57c1a_row2_col4 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_57c1a_row3_col0 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_57c1a_row3_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_57c1a_row3_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_57c1a_row3_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_57c1a_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_57c1a">
#   <caption>Years to retirement - starting_salary vs. interest_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57c1a_level0_col0" class="col_heading level0 col0" >0.030000</th>
#       <th id="T_57c1a_level0_col1" class="col_heading level0 col1" >0.040000</th>
#       <th id="T_57c1a_level0_col2" class="col_heading level0 col2" >0.050000</th>
#       <th id="T_57c1a_level0_col3" class="col_heading level0 col3" >0.060000</th>
#       <th id="T_57c1a_level0_col4" class="col_heading level0 col4" >0.070000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57c1a_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_57c1a_row0_col0" class="data row0 col0" >46.2</td>
#       <td id="T_57c1a_row0_col1" class="data row0 col1" >43.7</td>
#       <td id="T_57c1a_row0_col2" class="data row0 col2" >41.3</td>
#       <td id="T_57c1a_row0_col3" class="data row0 col3" >39.0</td>
#       <td id="T_57c1a_row0_col4" class="data row0 col4" >37.1</td>
#     </tr>
#     <tr>
#       <th id="T_57c1a_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_57c1a_row1_col0" class="data row1 col0" >40.6</td>
#       <td id="T_57c1a_row1_col1" class="data row1 col1" >38.4</td>
#       <td id="T_57c1a_row1_col2" class="data row1 col2" >36.4</td>
#       <td id="T_57c1a_row1_col3" class="data row1 col3" >34.5</td>
#       <td id="T_57c1a_row1_col4" class="data row1 col4" >32.8</td>
#     </tr>
#     <tr>
#       <th id="T_57c1a_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_57c1a_row2_col0" class="data row2 col0" >36.8</td>
#       <td id="T_57c1a_row2_col1" class="data row2 col1" >34.8</td>
#       <td id="T_57c1a_row2_col2" class="data row2 col2" >33.1</td>
#       <td id="T_57c1a_row2_col3" class="data row2 col3" >31.4</td>
#       <td id="T_57c1a_row2_col4" class="data row2 col4" >29.9</td>
#     </tr>
#     <tr>
#       <th id="T_57c1a_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_57c1a_row3_col0" class="data row3 col0" >33.8</td>
#       <td id="T_57c1a_row3_col1" class="data row3 col1" >32.1</td>
#       <td id="T_57c1a_row3_col2" class="data row3 col2" >30.5</td>
#       <td id="T_57c1a_row3_col3" class="data row3 col3" >29.1</td>
#       <td id="T_57c1a_row3_col4" class="data row3 col4" >27.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by starting_salary vs. desired_cash</h2>
# <style type="text/css">
# #T_55596_row0_col0, #T_55596_row1_col1, #T_55596_row2_col2, #T_55596_row3_col3 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_55596_row0_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_55596_row0_col2 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_55596_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_55596_row1_col0 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_55596_row1_col2 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_55596_row1_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_55596_row2_col0 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_55596_row2_col1 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_55596_row2_col3 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_55596_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_55596_row3_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_55596_row3_col2 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# </style>
# <table id="T_55596">
#   <caption>Years to retirement - starting_salary vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55596_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_55596_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_55596_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_55596_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >starting_salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55596_level0_row0" class="row_heading level0 row0" >20000</th>
#       <td id="T_55596_row0_col0" class="data row0 col0" >35.3</td>
#       <td id="T_55596_row0_col1" class="data row0 col1" >40.2</td>
#       <td id="T_55596_row0_col2" class="data row0 col2" >43.7</td>
#       <td id="T_55596_row0_col3" class="data row0 col3" >46.6</td>
#     </tr>
#     <tr>
#       <th id="T_55596_level0_row1" class="row_heading level0 row1" >30000</th>
#       <td id="T_55596_row1_col0" class="data row1 col0" >30.6</td>
#       <td id="T_55596_row1_col1" class="data row1 col1" >35.3</td>
#       <td id="T_55596_row1_col2" class="data row1 col2" >38.7</td>
#       <td id="T_55596_row1_col3" class="data row1 col3" >41.5</td>
#     </tr>
#     <tr>
#       <th id="T_55596_level0_row2" class="row_heading level0 row2" >40000</th>
#       <td id="T_55596_row2_col0" class="data row2 col0" >27.5</td>
#       <td id="T_55596_row2_col1" class="data row2 col1" >32.0</td>
#       <td id="T_55596_row2_col2" class="data row2 col2" >35.3</td>
#       <td id="T_55596_row2_col3" class="data row2 col3" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_55596_level0_row3" class="row_heading level0 row3" >50000</th>
#       <td id="T_55596_row3_col0" class="data row3 col0" >25.2</td>
#       <td id="T_55596_row3_col1" class="data row3 col1" >29.5</td>
#       <td id="T_55596_row3_col2" class="data row3 col2" >32.7</td>
#       <td id="T_55596_row3_col3" class="data row3 col3" >35.3</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promos_every_n_years vs. cost_of_living_raise</h2>
# <style type="text/css">
# #T_b122b_row0_col0 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_b122b_row0_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_b122b_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b122b_row1_col0 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_b122b_row1_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_b122b_row1_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_b122b_row2_col0 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_b122b_row2_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_b122b_row2_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_b122b_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b122b_row3_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_b122b_row3_col2 {
#   background-color: #fee08b;
#   color: #000000;
# }
# </style>
# <table id="T_b122b">
#   <caption>Years to retirement - promos_every_n_years vs. cost_of_living_raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b122b_level0_col0" class="col_heading level0 col0" >0.010000</th>
#       <th id="T_b122b_level0_col1" class="col_heading level0 col1" >0.020000</th>
#       <th id="T_b122b_level0_col2" class="col_heading level0 col2" >0.030000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promos_every_n_years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b122b_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b122b_row0_col0" class="data row0 col0" >31.9</td>
#       <td id="T_b122b_row0_col1" class="data row0 col1" >30.1</td>
#       <td id="T_b122b_row0_col2" class="data row0 col2" >28.5</td>
#     </tr>
#     <tr>
#       <th id="T_b122b_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_b122b_row1_col0" class="data row1 col0" >37.0</td>
#       <td id="T_b122b_row1_col1" class="data row1 col1" >34.6</td>
#       <td id="T_b122b_row1_col2" class="data row1 col2" >32.6</td>
#     </tr>
#     <tr>
#       <th id="T_b122b_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b122b_row2_col0" class="data row2 col0" >40.1</td>
#       <td id="T_b122b_row2_col1" class="data row2 col1" >37.4</td>
#       <td id="T_b122b_row2_col2" class="data row2 col2" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_b122b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_b122b_row3_col0" class="data row3 col0" >42.2</td>
#       <td id="T_b122b_row3_col1" class="data row3 col1" >39.3</td>
#       <td id="T_b122b_row3_col2" class="data row3 col2" >36.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promos_every_n_years vs. promo_raise</h2>
# <style type="text/css">
# #T_1d7be_row0_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_1d7be_row0_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_1d7be_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1d7be_row1_col0 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_1d7be_row1_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_1d7be_row1_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_1d7be_row2_col0 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_1d7be_row2_col1 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_1d7be_row2_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_1d7be_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1d7be_row3_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_1d7be_row3_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_1d7be">
#   <caption>Years to retirement - promos_every_n_years vs. promo_raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d7be_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_1d7be_level0_col1" class="col_heading level0 col1" >0.150000</th>
#       <th id="T_1d7be_level0_col2" class="col_heading level0 col2" >0.200000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promos_every_n_years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d7be_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_1d7be_row0_col0" class="data row0 col0" >34.0</td>
#       <td id="T_1d7be_row0_col1" class="data row0 col1" >29.8</td>
#       <td id="T_1d7be_row0_col2" class="data row0 col2" >26.6</td>
#     </tr>
#     <tr>
#       <th id="T_1d7be_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_1d7be_row1_col0" class="data row1 col0" >37.9</td>
#       <td id="T_1d7be_row1_col1" class="data row1 col1" >34.5</td>
#       <td id="T_1d7be_row1_col2" class="data row1 col2" >31.7</td>
#     </tr>
#     <tr>
#       <th id="T_1d7be_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_1d7be_row2_col0" class="data row2 col0" >40.2</td>
#       <td id="T_1d7be_row2_col1" class="data row2 col1" >37.4</td>
#       <td id="T_1d7be_row2_col2" class="data row2 col2" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_1d7be_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_1d7be_row3_col0" class="data row3 col0" >41.6</td>
#       <td id="T_1d7be_row3_col1" class="data row3 col1" >39.3</td>
#       <td id="T_1d7be_row3_col2" class="data row3 col2" >37.3</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promos_every_n_years vs. savings_rate</h2>
# <style type="text/css">
# #T_58b50_row0_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_58b50_row0_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_58b50_row0_col2 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_58b50_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_58b50_row1_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_58b50_row1_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_58b50_row1_col2 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_58b50_row1_col3 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_58b50_row2_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_58b50_row2_col1 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_58b50_row2_col2 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_58b50_row2_col3 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_58b50_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_58b50_row3_col1 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_58b50_row3_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_58b50_row3_col3 {
#   background-color: #91d068;
#   color: #000000;
# }
# </style>
# <table id="T_58b50">
#   <caption>Years to retirement - promos_every_n_years vs. savings_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58b50_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_58b50_level0_col1" class="col_heading level0 col1" >0.200000</th>
#       <th id="T_58b50_level0_col2" class="col_heading level0 col2" >0.300000</th>
#       <th id="T_58b50_level0_col3" class="col_heading level0 col3" >0.400000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promos_every_n_years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58b50_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_58b50_row0_col0" class="data row0 col0" >37.8</td>
#       <td id="T_58b50_row0_col1" class="data row0 col1" >31.0</td>
#       <td id="T_58b50_row0_col2" class="data row0 col2" >27.2</td>
#       <td id="T_58b50_row0_col3" class="data row0 col3" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_58b50_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_58b50_row1_col0" class="data row1 col0" >44.0</td>
#       <td id="T_58b50_row1_col1" class="data row1 col1" >35.7</td>
#       <td id="T_58b50_row1_col2" class="data row1 col2" >31.1</td>
#       <td id="T_58b50_row1_col3" class="data row1 col3" >28.0</td>
#     </tr>
#     <tr>
#       <th id="T_58b50_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_58b50_row2_col0" class="data row2 col0" >47.8</td>
#       <td id="T_58b50_row2_col1" class="data row2 col1" >38.6</td>
#       <td id="T_58b50_row2_col2" class="data row2 col2" >33.6</td>
#       <td id="T_58b50_row2_col3" class="data row2 col3" >30.1</td>
#     </tr>
#     <tr>
#       <th id="T_58b50_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_58b50_row3_col0" class="data row3 col0" >50.4</td>
#       <td id="T_58b50_row3_col1" class="data row3 col1" >40.6</td>
#       <td id="T_58b50_row3_col2" class="data row3 col2" >35.2</td>
#       <td id="T_58b50_row3_col3" class="data row3 col3" >31.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promos_every_n_years vs. interest_rate</h2>
# <style type="text/css">
# #T_d0067_row0_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_d0067_row0_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_d0067_row0_col2 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_d0067_row0_col3 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_d0067_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d0067_row1_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_d0067_row1_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_d0067_row1_col2, #T_d0067_row3_col4 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_d0067_row1_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_d0067_row1_col4 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_d0067_row2_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_d0067_row2_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_d0067_row2_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_d0067_row2_col3 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_d0067_row2_col4 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_d0067_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d0067_row3_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_d0067_row3_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_d0067_row3_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# </style>
# <table id="T_d0067">
#   <caption>Years to retirement - promos_every_n_years vs. interest_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0067_level0_col0" class="col_heading level0 col0" >0.030000</th>
#       <th id="T_d0067_level0_col1" class="col_heading level0 col1" >0.040000</th>
#       <th id="T_d0067_level0_col2" class="col_heading level0 col2" >0.050000</th>
#       <th id="T_d0067_level0_col3" class="col_heading level0 col3" >0.060000</th>
#       <th id="T_d0067_level0_col4" class="col_heading level0 col4" >0.070000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promos_every_n_years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0067_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_d0067_row0_col0" class="data row0 col0" >32.4</td>
#       <td id="T_d0067_row0_col1" class="data row0 col1" >31.3</td>
#       <td id="T_d0067_row0_col2" class="data row0 col2" >30.1</td>
#       <td id="T_d0067_row0_col3" class="data row0 col3" >29.0</td>
#       <td id="T_d0067_row0_col4" class="data row0 col4" >28.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0067_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_d0067_row1_col0" class="data row1 col0" >38.2</td>
#       <td id="T_d0067_row1_col1" class="data row1 col1" >36.4</td>
#       <td id="T_d0067_row1_col2" class="data row1 col2" >34.6</td>
#       <td id="T_d0067_row1_col3" class="data row1 col3" >33.0</td>
#       <td id="T_d0067_row1_col4" class="data row1 col4" >31.5</td>
#     </tr>
#     <tr>
#       <th id="T_d0067_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_d0067_row2_col0" class="data row2 col0" >42.1</td>
#       <td id="T_d0067_row2_col1" class="data row2 col1" >39.6</td>
#       <td id="T_d0067_row2_col2" class="data row2 col2" >37.4</td>
#       <td id="T_d0067_row2_col3" class="data row2 col3" >35.2</td>
#       <td id="T_d0067_row2_col4" class="data row2 col4" >33.4</td>
#     </tr>
#     <tr>
#       <th id="T_d0067_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_d0067_row3_col0" class="data row3 col0" >44.7</td>
#       <td id="T_d0067_row3_col1" class="data row3 col1" >41.8</td>
#       <td id="T_d0067_row3_col2" class="data row3 col2" >39.2</td>
#       <td id="T_d0067_row3_col3" class="data row3 col3" >36.8</td>
#       <td id="T_d0067_row3_col4" class="data row3 col4" >34.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promos_every_n_years vs. desired_cash</h2>
# <style type="text/css">
# #T_0649d_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0649d_row0_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_0649d_row0_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_0649d_row0_col3 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_0649d_row1_col0 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_0649d_row1_col1 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_0649d_row1_col2 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_0649d_row1_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_0649d_row2_col0 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_0649d_row2_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_0649d_row2_col2 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_0649d_row2_col3 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_0649d_row3_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_0649d_row3_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_0649d_row3_col2 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_0649d_row3_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0649d">
#   <caption>Years to retirement - promos_every_n_years vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0649d_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_0649d_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_0649d_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_0649d_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promos_every_n_years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0649d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0649d_row0_col0" class="data row0 col0" >25.5</td>
#       <td id="T_0649d_row0_col1" class="data row0 col1" >29.1</td>
#       <td id="T_0649d_row0_col2" class="data row0 col2" >31.9</td>
#       <td id="T_0649d_row0_col3" class="data row0 col3" >34.1</td>
#     </tr>
#     <tr>
#       <th id="T_0649d_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_0649d_row1_col0" class="data row1 col0" >29.1</td>
#       <td id="T_0649d_row1_col1" class="data row1 col1" >33.5</td>
#       <td id="T_0649d_row1_col2" class="data row1 col2" >36.8</td>
#       <td id="T_0649d_row1_col3" class="data row1 col3" >39.5</td>
#     </tr>
#     <tr>
#       <th id="T_0649d_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_0649d_row2_col0" class="data row2 col0" >31.3</td>
#       <td id="T_0649d_row2_col1" class="data row2 col1" >36.2</td>
#       <td id="T_0649d_row2_col2" class="data row2 col2" >39.8</td>
#       <td id="T_0649d_row2_col3" class="data row2 col3" >42.8</td>
#     </tr>
#     <tr>
#       <th id="T_0649d_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_0649d_row3_col0" class="data row3 col0" >32.7</td>
#       <td id="T_0649d_row3_col1" class="data row3 col1" >38.0</td>
#       <td id="T_0649d_row3_col2" class="data row3 col2" >41.9</td>
#       <td id="T_0649d_row3_col3" class="data row3 col3" >45.0</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by cost_of_living_raise vs. promo_raise</h2>
# <style type="text/css">
# #T_ceb9d_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ceb9d_row0_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_ceb9d_row0_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_ceb9d_row1_col0 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_ceb9d_row1_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_ceb9d_row1_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_ceb9d_row2_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_ceb9d_row2_col1 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_ceb9d_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ceb9d">
#   <caption>Years to retirement - cost_of_living_raise vs. promo_raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ceb9d_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_ceb9d_level0_col1" class="col_heading level0 col1" >0.150000</th>
#       <th id="T_ceb9d_level0_col2" class="col_heading level0 col2" >0.200000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cost_of_living_raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceb9d_level0_row0" class="row_heading level0 row0" >0.010000</th>
#       <td id="T_ceb9d_row0_col0" class="data row0 col0" >41.2</td>
#       <td id="T_ceb9d_row0_col1" class="data row0 col1" >37.6</td>
#       <td id="T_ceb9d_row0_col2" class="data row0 col2" >34.7</td>
#     </tr>
#     <tr>
#       <th id="T_ceb9d_level0_row1" class="row_heading level0 row1" >0.020000</th>
#       <td id="T_ceb9d_row1_col0" class="data row1 col0" >38.3</td>
#       <td id="T_ceb9d_row1_col1" class="data row1 col1" >35.2</td>
#       <td id="T_ceb9d_row1_col2" class="data row1 col2" >32.6</td>
#     </tr>
#     <tr>
#       <th id="T_ceb9d_level0_row2" class="row_heading level0 row2" >0.030000</th>
#       <td id="T_ceb9d_row2_col0" class="data row2 col0" >35.9</td>
#       <td id="T_ceb9d_row2_col1" class="data row2 col1" >33.0</td>
#       <td id="T_ceb9d_row2_col2" class="data row2 col2" >30.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by cost_of_living_raise vs. savings_rate</h2>
# <style type="text/css">
# #T_2dbc7_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2dbc7_row0_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_2dbc7_row0_col2 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_2dbc7_row0_col3 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_2dbc7_row1_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_2dbc7_row1_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_2dbc7_row1_col2 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_2dbc7_row1_col3 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_2dbc7_row2_col0 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_2dbc7_row2_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_2dbc7_row2_col2 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_2dbc7_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2dbc7">
#   <caption>Years to retirement - cost_of_living_raise vs. savings_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dbc7_level0_col0" class="col_heading level0 col0" >0.100000</th>
#       <th id="T_2dbc7_level0_col1" class="col_heading level0 col1" >0.200000</th>
#       <th id="T_2dbc7_level0_col2" class="col_heading level0 col2" >0.300000</th>
#       <th id="T_2dbc7_level0_col3" class="col_heading level0 col3" >0.400000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cost_of_living_raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dbc7_level0_row0" class="row_heading level0 row0" >0.010000</th>
#       <td id="T_2dbc7_row0_col0" class="data row0 col0" >48.3</td>
#       <td id="T_2dbc7_row0_col1" class="data row0 col1" >38.9</td>
#       <td id="T_2dbc7_row0_col2" class="data row0 col2" >33.8</td>
#       <td id="T_2dbc7_row0_col3" class="data row0 col3" >30.3</td>
#     </tr>
#     <tr>
#       <th id="T_2dbc7_level0_row1" class="row_heading level0 row1" >0.020000</th>
#       <td id="T_2dbc7_row1_col0" class="data row1 col0" >44.9</td>
#       <td id="T_2dbc7_row1_col1" class="data row1 col1" >36.4</td>
#       <td id="T_2dbc7_row1_col2" class="data row1 col2" >31.7</td>
#       <td id="T_2dbc7_row1_col3" class="data row1 col3" >28.5</td>
#     </tr>
#     <tr>
#       <th id="T_2dbc7_level0_row2" class="row_heading level0 row2" >0.030000</th>
#       <td id="T_2dbc7_row2_col0" class="data row2 col0" >41.9</td>
#       <td id="T_2dbc7_row2_col1" class="data row2 col1" >34.1</td>
#       <td id="T_2dbc7_row2_col2" class="data row2 col2" >29.8</td>
#       <td id="T_2dbc7_row2_col3" class="data row2 col3" >26.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by cost_of_living_raise vs. interest_rate</h2>
# <style type="text/css">
# #T_a0d18_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a0d18_row0_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_a0d18_row0_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_a0d18_row0_col3 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_a0d18_row0_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_a0d18_row1_col0 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a0d18_row1_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_a0d18_row1_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_a0d18_row1_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_a0d18_row1_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_a0d18_row2_col0 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a0d18_row2_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_a0d18_row2_col2 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_a0d18_row2_col3 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_a0d18_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0d18">
#   <caption>Years to retirement - cost_of_living_raise vs. interest_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0d18_level0_col0" class="col_heading level0 col0" >0.030000</th>
#       <th id="T_a0d18_level0_col1" class="col_heading level0 col1" >0.040000</th>
#       <th id="T_a0d18_level0_col2" class="col_heading level0 col2" >0.050000</th>
#       <th id="T_a0d18_level0_col3" class="col_heading level0 col3" >0.060000</th>
#       <th id="T_a0d18_level0_col4" class="col_heading level0 col4" >0.070000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cost_of_living_raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0d18_level0_row0" class="row_heading level0 row0" >0.010000</th>
#       <td id="T_a0d18_row0_col0" class="data row0 col0" >42.6</td>
#       <td id="T_a0d18_row0_col1" class="data row0 col1" >40.0</td>
#       <td id="T_a0d18_row0_col2" class="data row0 col2" >37.6</td>
#       <td id="T_a0d18_row0_col3" class="data row0 col3" >35.4</td>
#       <td id="T_a0d18_row0_col4" class="data row0 col4" >33.5</td>
#     </tr>
#     <tr>
#       <th id="T_a0d18_level0_row1" class="row_heading level0 row1" >0.020000</th>
#       <td id="T_a0d18_row1_col0" class="data row1 col0" >39.2</td>
#       <td id="T_a0d18_row1_col1" class="data row1 col1" >37.1</td>
#       <td id="T_a0d18_row1_col2" class="data row1 col2" >35.2</td>
#       <td id="T_a0d18_row1_col3" class="data row1 col3" >33.4</td>
#       <td id="T_a0d18_row1_col4" class="data row1 col4" >31.8</td>
#     </tr>
#     <tr>
#       <th id="T_a0d18_level0_row2" class="row_heading level0 row2" >0.030000</th>
#       <td id="T_a0d18_row2_col0" class="data row2 col0" >36.2</td>
#       <td id="T_a0d18_row2_col1" class="data row2 col1" >34.6</td>
#       <td id="T_a0d18_row2_col2" class="data row2 col2" >33.1</td>
#       <td id="T_a0d18_row2_col3" class="data row2 col3" >31.7</td>
#       <td id="T_a0d18_row2_col4" class="data row2 col4" >30.3</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by cost_of_living_raise vs. desired_cash</h2>
# <style type="text/css">
# #T_26377_row0_col0 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_26377_row0_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_26377_row0_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_26377_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_26377_row1_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_26377_row1_col1 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_26377_row1_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_26377_row1_col3 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_26377_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_26377_row2_col1 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_26377_row2_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_26377_row2_col3 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# </style>
# <table id="T_26377">
#   <caption>Years to retirement - cost_of_living_raise vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26377_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_26377_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_26377_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_26377_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cost_of_living_raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26377_level0_row0" class="row_heading level0 row0" >0.010000</th>
#       <td id="T_26377_row0_col0" class="data row0 col0" >31.5</td>
#       <td id="T_26377_row0_col1" class="data row0 col1" >36.5</td>
#       <td id="T_26377_row0_col2" class="data row0 col2" >40.2</td>
#       <td id="T_26377_row0_col3" class="data row0 col3" >43.2</td>
#     </tr>
#     <tr>
#       <th id="T_26377_level0_row1" class="row_heading level0 row1" >0.020000</th>
#       <td id="T_26377_row1_col0" class="data row1 col0" >29.6</td>
#       <td id="T_26377_row1_col1" class="data row1 col1" >34.1</td>
#       <td id="T_26377_row1_col2" class="data row1 col2" >37.5</td>
#       <td id="T_26377_row1_col3" class="data row1 col3" >40.2</td>
#     </tr>
#     <tr>
#       <th id="T_26377_level0_row2" class="row_heading level0 row2" >0.030000</th>
#       <td id="T_26377_row2_col0" class="data row2 col0" >27.9</td>
#       <td id="T_26377_row2_col1" class="data row2 col1" >32.1</td>
#       <td id="T_26377_row2_col2" class="data row2 col2" >35.2</td>
#       <td id="T_26377_row2_col3" class="data row2 col3" >37.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promo_raise vs. savings_rate</h2>
# <style type="text/css">
# #T_fa7c8_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_fa7c8_row0_col1 {
#   background-color: #fee797;
#   color: #000000;
# }
# ...
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af19e_level0_row0" class="row_heading level0 row0" >0.100000</th>
#       <td id="T_af19e_row0_col0" class="data row0 col0" >43.5</td>
#       <td id="T_af19e_row0_col1" class="data row0 col1" >40.7</td>
#       <td id="T_af19e_row0_col2" class="data row0 col2" >38.2</td>
#       <td id="T_af19e_row0_col3" class="data row0 col3" >35.9</td>
#       <td id="T_af19e_row0_col4" class="data row0 col4" >33.9</td>
#     </tr>
#     <tr>
#       <th id="T_af19e_level0_row1" class="row_heading level0 row1" >0.150000</th>
#       <td id="T_af19e_row1_col0" class="data row1 col0" >39.0</td>
#       <td id="T_af19e_row1_col1" class="data row1 col1" >37.0</td>
#       <td id="T_af19e_row1_col2" class="data row1 col2" >35.1</td>
#       <td id="T_af19e_row1_col3" class="data row1 col3" >33.4</td>
#       <td id="T_af19e_row1_col4" class="data row1 col4" >31.8</td>
#     </tr>
#     <tr>
#       <th id="T_af19e_level0_row2" class="row_heading level0 row2" >0.200000</th>
#       <td id="T_af19e_row2_col0" class="data row2 col0" >35.5</td>
#       <td id="T_af19e_row2_col1" class="data row2 col1" >34.0</td>
#       <td id="T_af19e_row2_col2" class="data row2 col2" >32.6</td>
#       <td id="T_af19e_row2_col3" class="data row2 col3" >31.2</td>
#       <td id="T_af19e_row2_col4" class="data row2 col4" >29.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by promo_raise vs. desired_cash</h2>
# <style type="text/css">
# #T_84995_row0_col0 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_84995_row0_col1 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_84995_row0_col2 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_84995_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_84995_row1_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_84995_row1_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_84995_row1_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_84995_row1_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_84995_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_84995_row2_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_84995_row2_col2 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_84995_row2_col3 {
#   background-color: #fee797;
#   color: #000000;
# }
# </style>
# <table id="T_84995">
#   <caption>Years to retirement - promo_raise vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84995_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_84995_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_84995_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_84995_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >promo_raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84995_level0_row0" class="row_heading level0 row0" >0.100000</th>
#       <td id="T_84995_row0_col0" class="data row0 col0" >31.9</td>
#       <td id="T_84995_row0_col1" class="data row0 col1" >37.1</td>
#       <td id="T_84995_row0_col2" class="data row0 col2" >40.9</td>
#       <td id="T_84995_row0_col3" class="data row0 col3" >43.9</td>
#     </tr>
#     <tr>
#       <th id="T_84995_level0_row1" class="row_heading level0 row1" >0.150000</th>
#       <td id="T_84995_row1_col0" class="data row1 col0" >29.5</td>
#       <td id="T_84995_row1_col1" class="data row1 col1" >34.0</td>
#       <td id="T_84995_row1_col2" class="data row1 col2" >37.4</td>
#       <td id="T_84995_row1_col3" class="data row1 col3" >40.1</td>
#     </tr>
#     <tr>
#       <th id="T_84995_level0_row2" class="row_heading level0 row2" >0.200000</th>
#       <td id="T_84995_row2_col0" class="data row2 col0" >27.5</td>
#       <td id="T_84995_row2_col1" class="data row2 col1" >31.6</td>
#       <td id="T_84995_row2_col2" class="data row2 col2" >34.6</td>
#       <td id="T_84995_row2_col3" class="data row2 col3" >37.0</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by savings_rate vs. interest_rate</h2>
# <style type="text/css">
# #T_5faad_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5faad_row0_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_5faad_row0_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_5faad_row0_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_5faad_row0_col4 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_5faad_row1_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_5faad_row1_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_5faad_row1_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_5faad_row1_col3 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_5faad_row1_col4 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_5faad_row2_col0 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_5faad_row2_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_5faad_row2_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_5faad_row2_col3 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_5faad_row2_col4 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_5faad_row3_col0 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_5faad_row3_col1 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_5faad_row3_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_5faad_row3_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_5faad_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5faad">
#   <caption>Years to retirement - savings_rate vs. interest_rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5faad_level0_col0" class="col_heading level0 col0" >0.030000</th>
#       <th id="T_5faad_level0_col1" class="col_heading level0 col1" >0.040000</th>
#       <th id="T_5faad_level0_col2" class="col_heading level0 col2" >0.050000</th>
#       <th id="T_5faad_level0_col3" class="col_heading level0 col3" >0.060000</th>
#       <th id="T_5faad_level0_col4" class="col_heading level0 col4" >0.070000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >savings_rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5faad_level0_row0" class="row_heading level0 row0" >0.100000</th>
#       <td id="T_5faad_row0_col0" class="data row0 col0" >50.3</td>
#       <td id="T_5faad_row0_col1" class="data row0 col1" >47.5</td>
#       <td id="T_5faad_row0_col2" class="data row0 col2" >44.8</td>
#       <td id="T_5faad_row0_col3" class="data row0 col3" >42.3</td>
#       <td id="T_5faad_row0_col4" class="data row0 col4" >40.1</td>
#     </tr>
#     <tr>
#       <th id="T_5faad_level0_row1" class="row_heading level0 row1" >0.200000</th>
#       <td id="T_5faad_row1_col0" class="data row1 col0" >40.5</td>
#       <td id="T_5faad_row1_col1" class="data row1 col1" >38.3</td>
#       <td id="T_5faad_row1_col2" class="data row1 col2" >36.3</td>
#       <td id="T_5faad_row1_col3" class="data row1 col3" >34.5</td>
#       <td id="T_5faad_row1_col4" class="data row1 col4" >32.8</td>
#     </tr>
#     <tr>
#       <th id="T_5faad_level0_row2" class="row_heading level0 row2" >0.300000</th>
#       <td id="T_5faad_row2_col0" class="data row2 col0" >35.1</td>
#       <td id="T_5faad_row2_col1" class="data row2 col1" >33.3</td>
#       <td id="T_5faad_row2_col2" class="data row2 col2" >31.6</td>
#       <td id="T_5faad_row2_col3" class="data row2 col3" >30.1</td>
#       <td id="T_5faad_row2_col4" class="data row2 col4" >28.7</td>
#     </tr>
#     <tr>
#       <th id="T_5faad_level0_row3" class="row_heading level0 row3" >0.400000</th>
#       <td id="T_5faad_row3_col0" class="data row3 col0" >31.5</td>
#       <td id="T_5faad_row3_col1" class="data row3 col1" >29.9</td>
#       <td id="T_5faad_row3_col2" class="data row3 col2" >28.5</td>
#       <td id="T_5faad_row3_col3" class="data row3 col3" >27.1</td>
#       <td id="T_5faad_row3_col4" class="data row3 col4" >25.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by savings_rate vs. desired_cash</h2>
# <style type="text/css">
# #T_ce0bd_row0_col0, #T_ce0bd_row1_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_ce0bd_row0_col1 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_ce0bd_row0_col2 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_ce0bd_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ce0bd_row1_col0, #T_ce0bd_row2_col1, #T_ce0bd_row3_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_ce0bd_row1_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_ce0bd_row1_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_ce0bd_row2_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_ce0bd_row2_col2 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_ce0bd_row2_col3 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_ce0bd_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ce0bd_row3_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_ce0bd_row3_col3 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# </style>
# <table id="T_ce0bd">
#   <caption>Years to retirement - savings_rate vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce0bd_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_ce0bd_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_ce0bd_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_ce0bd_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >savings_rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce0bd_level0_row0" class="row_heading level0 row0" >0.100000</th>
#       <td id="T_ce0bd_row0_col0" class="data row0 col0" >38.7</td>
#       <td id="T_ce0bd_row0_col1" class="data row0 col1" >43.7</td>
#       <td id="T_ce0bd_row0_col2" class="data row0 col2" >47.4</td>
#       <td id="T_ce0bd_row0_col3" class="data row0 col3" >50.3</td>
#     </tr>
#     <tr>
#       <th id="T_ce0bd_level0_row1" class="row_heading level0 row1" >0.200000</th>
#       <td id="T_ce0bd_row1_col0" class="data row1 col0" >30.6</td>
#       <td id="T_ce0bd_row1_col1" class="data row1 col1" >35.2</td>
#       <td id="T_ce0bd_row1_col2" class="data row1 col2" >38.7</td>
#       <td id="T_ce0bd_row1_col3" class="data row1 col3" >41.4</td>
#     </tr>
#     <tr>
#       <th id="T_ce0bd_level0_row2" class="row_heading level0 row2" >0.300000</th>
#       <td id="T_ce0bd_row2_col0" class="data row2 col0" >26.2</td>
#       <td id="T_ce0bd_row2_col1" class="data row2 col1" >30.6</td>
#       <td id="T_ce0bd_row2_col2" class="data row2 col2" >33.8</td>
#       <td id="T_ce0bd_row2_col3" class="data row2 col3" >36.5</td>
#     </tr>
#     <tr>
#       <th id="T_ce0bd_level0_row3" class="row_heading level0 row3" >0.400000</th>
#       <td id="T_ce0bd_row3_col0" class="data row3 col0" >23.2</td>
#       <td id="T_ce0bd_row3_col1" class="data row3 col1" >27.4</td>
#       <td id="T_ce0bd_row3_col2" class="data row3 col2" >30.6</td>
#       <td id="T_ce0bd_row3_col3" class="data row3 col3" >33.1</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to retirement by interest_rate vs. desired_cash</h2>
# <style type="text/css">
# #T_9c739_row0_col0 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_9c739_row0_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_9c739_row0_col2 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_9c739_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9c739_row1_col0 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_9c739_row1_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_9c739_row1_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_9c739_row1_col3 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_9c739_row2_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_9c739_row2_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_9c739_row2_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_9c739_row2_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_9c739_row3_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_9c739_row3_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_9c739_row3_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_9c739_row3_col3 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_9c739_row4_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9c739_row4_col1 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_9c739_row4_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_9c739_row4_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# </style>
# <table id="T_9c739">
#   <caption>Years to retirement - interest_rate vs. desired_cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c739_level0_col0" class="col_heading level0 col0" >1000000</th>
#       <th id="T_9c739_level0_col1" class="col_heading level0 col1" >1500000</th>
#       <th id="T_9c739_level0_col2" class="col_heading level0 col2" >2000000</th>
#       <th id="T_9c739_level0_col3" class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >interest_rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c739_level0_row0" class="row_heading level0 row0" >0.030000</th>
#       <td id="T_9c739_row0_col0" class="data row0 col0" >32.7</td>
#       <td id="T_9c739_row0_col1" class="data row0 col1" >37.9</td>
#       <td id="T_9c739_row0_col2" class="data row0 col2" >41.8</td>
#       <td id="T_9c739_row0_col3" class="data row0 col3" >44.9</td>
#     </tr>
#     <tr>
#       <th id="T_9c739_level0_row1" class="row_heading level0 row1" >0.040000</th>
#       <td id="T_9c739_row1_col0" class="data row1 col0" >31.0</td>
#       <td id="T_9c739_row1_col1" class="data row1 col1" >35.9</td>
#       <td id="T_9c739_row1_col2" class="data row1 col2" >39.5</td>
#       <td id="T_9c739_row1_col3" class="data row1 col3" >42.5</td>
#     </tr>
#     <tr>
#       <th id="T_9c739_level0_row2" class="row_heading level0 row2" >0.050000</th>
#       <td id="T_9c739_row2_col0" class="data row2 col0" >29.5</td>
#       <td id="T_9c739_row2_col1" class="data row2 col1" >34.1</td>
#       <td id="T_9c739_row2_col2" class="data row2 col2" >37.5</td>
#       <td id="T_9c739_row2_col3" class="data row2 col3" >40.2</td>
#     </tr>
#     <tr>
#       <th id="T_9c739_level0_row3" class="row_heading level0 row3" >0.060000</th>
#       <td id="T_9c739_row3_col0" class="data row3 col0" >28.1</td>
#       <td id="T_9c739_row3_col1" class="data row3 col1" >32.4</td>
#       <td id="T_9c739_row3_col2" class="data row3 col2" >35.5</td>
#       <td id="T_9c739_row3_col3" class="data row3 col3" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_9c739_level0_row4" class="row_heading level0 row4" >0.070000</th>
#       <td id="T_9c739_row4_col0" class="data row4 col0" >26.8</td>
#       <td id="T_9c739_row4_col1" class="data row4 col1" >30.8</td>
#       <td id="T_9c739_row4_col2" class="data row4 col2" >33.7</td>
#       <td id="T_9c739_row4_col3" class="data row4 col3" >36.1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #

# %% [markdown]
# # What-if analysis

# %% [markdown]
# ### Specify the good and bad economies

# %%
#  The function to calculate bad economy:
bad_economy_data = ModelInputs(
    starting_salary=10000,
    promos_every_n_years=8,
    cost_of_living_raise=0.01,
    promo_raise=0.07,
    savings_rate=0.15,
    interest_rate=0.03)

# The function for good economy:
good_economy_data = ModelInputs(
    starting_salary=40000,
    promos_every_n_years=2,
    cost_of_living_raise=0.03,
    promo_raise=0.20,
    savings_rate=0.35,
    interest_rate=0.06)

cases = {
    'Bad': bad_economy_data,
    # Original inputs were set to assume a 'normal' economy
    'Normal': model_data, 
    'Good': good_economy_data}

# %%
# Run the model with the three scenarios and print the results:
for case_type, case_inputs in cases.items():
    ytr = years_to_retirement(case_inputs, print_output=False)
    # How long to retire in a good economy?
    print(f"It would take {ytr} years to retire in a {case_type} economy.")
# Out:
# It would take 86 years to retire in a Bad economy.
# It would take 27 years to retire in a Normal economy.
# It would take 17 years to retire in a Good economy.

# %% [markdown]
# #

# %% [markdown]
# # Assigning probabilities

# %%
# These values are arbitrary and are only used for demonstration. 
case_probabilities = {
    'Bad': 0.2,
    'Normal': 0.5,
    'Good': 0.3}

# Run the model by taking the expected value over the three cases;
# print the results with a text string:
expected_ytr = 0
for case_type, case_inputs in cases.items():
    ytr = years_to_retirement(case_inputs, print_output=False)
    weighted_ytr = ytr * case_probabilities[case_type]
    expected_ytr += weighted_ytr
    
print(f"It would take {expected_ytr:.0f} years to retire given a \
{case_probabilities['Bad']:.0%} \
chance of a bad economy and {case_probabilities['Good']:.0%} \
chance of a good economy.")
# Out:
# It would take 36 years to retire given a 20% chance of a bad economy and 30% chance of a good economy.
