# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics using Python
#
# ## Connecting and retrieving (tutorial video)  |  Twitter API replacemnt
#
# Twitter has announced they will no longer support free access to the Twitter API. This means, that without a paid account you will not be able to follow the demonstration.
#
# First, confirm that you are unable to access the API directly. Should you be unable to access the API directly, you can use the JSON files and code provided here to follow the demonstration.

# %%
# Install Twitter api.
# !pip install twitter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# Import
import pandas as pd
import json
import yaml
from yaml.loader import SafeLoader
#from twitter import *

# %%
# Import the yaml file - remember to specify the whole path
twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/2y/jw_fvb1s0nncctnyn9dc159w0000gn/T/ipykernel_9108/1715009312.py in <module>
#       1 # Import the yaml file - remember to specify the whole path
# ----> 2 twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'twitter.yaml'

# %%
# Pass your twitter credentials
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key']))
# See if you are connected
print(twitter_api)

# %% [markdown]
# If you are connected to the Twitter API you can continue to follow the demonstration. You do not need to use the JSON files.
#
# If you are NOT connected to the Twitter API you will need to use the JSON files provided.
#
# For reference, the cells below show how the JSON files were obtained.

# %%
# For reference only: Run a test with #python and view the output
# some_python_tweets = twitter_api.search.tweets(q="#python")
# print(some_python_tweets)

# %%
# For reference only: Command used to save the output to JSON
# with open("some_python_tweets.json", "w") as outfile:
# json.dump(some_python_tweets, outfile)

# %% [markdown]
# The JSON data files provided contain the raw JSON dumps of the Twitter API calls.
#
# Use the code below to replace the existing API calls. When you load the JSON file you will be able to follow the rest of the demonstration.
#
# **For the 'Connecting and retrieving' (tutorial video) demonstration the JSON file is:**
# - some_python_tweets.json
#
# Make sure that you place the provided data files in the correct directory, or change the relative directory to point to the correct location.

# %%
# Proceed to this cell to load the data from JSON
#.  Note that the variable names will differ depending on the step

# Opening JSON file to be used as substitute for live access
with open('some_python_tweets.json', 'r') as openfile:
    some_python_tweets = json.load(openfile)

# view output
print(some_python_tweets)
# Out:
# {'statuses': [{'created_at': 'Tue Feb 07 03:11:14 +0000 2023', 'id': 1622795091143192576, 'id_str': '1622795091143192576', 'text': 'คุยง่าย เก็บความลับลูกค้า Line : @365xgali #รับเขียนโปรแกรม #เขียนโปรแกรม #python #C #arduino #php #html #css #js… https://t.co/Gse6GUy1IJ', 'truncated': True, 'entities': {'hashtags': [{'text': 'รับเขียนโปรแกรม', 'indices': [43, 59]}, {'text': 'เขียนโปรแกรม', 'indices': [60, 73]}, {'text': 'python', 'indices': [74, 81]}, {'text': 'C', 'indices': [82, 84]}, {'text': 'arduino', 'indices': [85, 93]}, {'text': 'php', 'indices': [94, 98]}, {'text': 'html', 'indices': [99, 104]}, {'text': 'css', 'indices': [105, 109]}, {'text': 'js', 'indices': [110, 113]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Gse6GUy1IJ', 'expanded_url': 'https://twitter.com/i/web/status/1622795091143192576', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}]}, 'metadata': {'iso_language_code': 'th', 'result_type': 'recent'}, 'source': '<a hr
# ...
