# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics using Python

# %% [markdown]
# ## API: Connecting and retrieving (tutorial video)

# %% [markdown]
# This Notebook accompanies the **API: Connecting and retrieving** demonstration video. Follow along with the demonstration to learn how to:
# - request access
# - retrieve headers
# - retrieve header values
# - formating the JSON response.

# %% [markdown]
# # Prepare your workstation

# %%
# Install JSON and requests if needed.
# !pip install json
# !pip install requests

# %%
# Import libraries.
import requests
import json

# %% [markdown]
# # 1. Request access

# %%
# Identify the URL to connect to.
# Create a variable to store the URL.
URL = 'https://api.coingecko.com/api/v3/exchange_rates'

# Send connect request.
response = requests.get(url=URL)

# View answer from URL.
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# # 2. Retrieve headers

# %% [markdown]
# What if you do not get a `200 status_code`? Can you still access some information from the API? Yes, you can!

# %%
# Write if and else statements to get information and status_code.
if response.status_code == 200:
    print(response.headers)
else:
    print(response.status_code)
    response.headers['Content-Encoding']
# Out:
# {'Date': 'Sat, 18 Feb 2023 20:18:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '0', 'X-Content-Type-Options': 'nosniff', 'X-Download-Options': 'noopen', 'X-Permitted-Cross-Domain-Policies': 'none', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'Cache-Control': 'public, max-age=120', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'POST, PUT, DELETE, GET, OPTIONS', 'Access-Control-Request-Method': '*', 'Access-Control-Allow-Headers': 'Origin, X-Requested-With, Content-Type, Accept, Authorization', 'Access-Control-Expose-Headers': 'link, per-page, total', 'Vary': 'Accept-Encoding, Origin', 'ETag': 'W/"031508eda1fe4266175824cb7b41b4d1"', 'X-Request-Id': '03ac0e01-4015-46b0-91fd-cbfd8329b13c', 'X-Runtime': '0.014827', 'Alternate-Protocol': '443:npn-spdy/2', 'CF-Cache-Status': 'HIT', 'Age': '6', 'Expires': 'Sat, 18 Feb 2023 20:20:31 GMT', 'Set-Cookie': '__cf_bm=WUYlq23A1TRyF1SMoV2xdsnhewaZRCLpiW0uOcFDczU-1676751511-0-AZpQ8fHfG06iMApeeesG0VLlaB5tR/jX5p/2bLo7vKlxq/O1WXBPUBUuhDnauzCHAd17wzpi7eaSaXcNFN8Qqfc=; path=/; expires=Sat, 18-Feb-23 20:48:31 GMT; domain=.api.coingecko.com; HttpOnly; Secure; SameSite=None', 'Server': 'cloudflare', 'CF-RAY': '79b973d34d1f754d-LHR', 'Content-Encoding': 'br'}

# %% [markdown]
# # 3. Retrieve header values

# %%
# Retrieving header values with a key.
print(response.headers['Date'])
# Out:
# Sat, 18 Feb 2023 20:18:31 GMT

# %%
# Retrieving header values with a key.
print(response.headers['Access-Control-Allow-Methods'])
# Out:
# POST, PUT, DELETE, GET, OPTIONS

# %% [markdown]
# # 4. Retrieve information from API

# %%
# Retrieve the payload of the API.
response.text
# Out:
# '{"rates":{"btc":{"name":"Bitcoin","unit":"BTC","value":1.0,"type":"crypto"},"eth":{"name":"Ether","unit":"ETH","value":14.583,"type":"crypto"},"ltc":{"name":"Litecoin","unit":"LTC","value":247.572,"type":"crypto"},"bch":{"name":"Bitcoin Cash","unit":"BCH","value":181.8,"type":"crypto"},"bnb":{"name":"Binance Coin","unit":"BNB","value":78.062,"type":"crypto"},"eos":{"name":"EOS","unit":"EOS","value":19980.52,"type":"crypto"},"xrp":{"name":"XRP","unit":"XRP","value":62590.731,"type":"crypto"},"xlm":{"name":"Lumens","unit":"XLM","value":268207.128,"type":"crypto"},"link":{"name":"Chainlink","unit":"LINK","value":3061.383,"type":"crypto"},"dot":{"name":"Polkadot","unit":"DOT","value":3415.044,"type":"crypto"},"yfi":{"name":"Yearn.finance","unit":"YFI","value":3.336,"type":"crypto"},"usd":{"name":"US Dollar","unit":"$","value":24602.651,"type":"fiat"},"aed":{"name":"United Arab Emirates Dirham","unit":"DH","value":90364.309,"type":"fiat"},"ars":{"name":"Argentine Peso","unit":"$","value":4739053.451,"type":"fiat"},"aud":{"name":"Australian Dollar","unit":"A$","value":35764.874,"type":"fiat"},"bdt":{"name":"Bangladeshi Taka","unit":"৳","value":2579701.902,"type":"fiat"},"bhd":{"name":"Bahraini Dinar","unit":"BD","value":9249.957,"type":"fiat"},"bmd":{"name":"Bermudian Dollar","unit":"$","value":24602.651,"type":"fiat"},"brl":{"name":"Brazil Real","unit":"R$","value":127107.14,"type":"fiat"},"cad":{"name":"Canadian Dollar","unit":"CA$","value":33150.843,"type":"fiat"},"chf":{"name":"Swiss Franc","unit":"Fr.","value":22756.025,"type":"fiat"},"clp":{"name":"Chilean Peso","unit":"CLP$","value":19420103.202,"type":"fiat"},"cny":{"name":"Chinese Yuan","unit":"¥","value":168961.171,"type":"fiat"},"czk":{"name":"Czech Koruna","unit":"Kč","value":545182.462,"type":"fiat"},"dkk":{"name":"Danish Krone","unit":"kr.","value":171288.582,"type":"fiat"},"eur":{"name":"Euro","unit":"€","value":22957.743,"type":"fiat"},"gbp":{"name":"British Pound Sterling","unit":"£","value":20427.311,"type":"fiat"},"hkd":{"name":"Hong Kong Dollar","unit":"HK$","value":193036.096,"type":"fiat"},"huf":{"name":"Hungarian Forint","unit":"Ft","value":8827431.467,"type":"fiat"},"idr":{"name":"Indonesian Rupiah","unit":"Rp","value":373106716.689,"type":"fiat"},"ils":{"name":"Israeli New Shekel","unit":"₪","value":87373.857,"type":"fiat"},"inr":{"name":"Indian Rupee","unit":"₹","value":2037447.697,"type":"fiat"},"jpy":{"name":"Japanese Yen","unit":"¥","value":3299337.969,"type":"fiat"},"krw":{"name":"South Korean Won","unit":"₩","value":31881100.315,"type":"fiat"},"kwd":{"name":"Kuwaiti Dinar","unit":"KD","value":7537.514,"type":"fiat"},"lkr":{"name":"Sri Lankan Rupee","unit":"Rs","value":8994897.56,"type":"fiat"},"mmk":{"name":"Burmese Kyat","unit":"K","value":51680803.589,"type":"fiat"},"mxn":{"name":"Mexican Peso","unit":"MX$","value":451734.21,"type":"fiat"},"myr":{"name":"Malaysian Ringgit","unit":"RM","value":109038.952,"type":"fiat"},"ngn":{"name":"Nigerian Naira","unit":"₦","value":11330505.262,"type":"fiat"},"nok":{"name":"Norwegian Krone","unit":"kr","value":253028.432,"type":"fiat"},"nzd":{"name":"New Zealand Dollar","unit":"NZ$","value":39395.758,"type":"fiat"},"php":{"name":"Philippine Peso","unit":"₱","value":1361141.809,"type":"fiat"},"pkr":{"name":"Pakistani Rupee","unit":"₨","value":6469882.358,"type":"fiat"},"pln":{"name":"Polish Zloty","unit":"zł","value":109465.808,"type":"fiat"},"rub":{"name":"Russian Ruble","unit":"₽","value":1821069.711,"type":"fiat"},"sar":{"name":"Saudi Riyal","unit":"SR","value":92203.456,"type":"fiat"},"sek":{"name":"Swedish Krona","unit":"kr","value":257127.234,"type":"fiat"},"sgd":{"name":"Singapore Dollar","unit":"S$","value":32893.745,"type":"fiat"},"thb":{"name":"Thai Baht","unit":"฿","value":845404.243,"type":"fiat"},"try":{"name":"Turkish Lira","unit":"₺","value":463240.87,"type":"fiat"},"twd":{"name":"New Taiwan Dollar","unit":"NT$","value":747645.065,"type":"fiat"},"uah":{"name":"Ukrainian hryvnia","unit":"₴","value":90 ...

# %%
# Type of content.
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# # 5. Format JSON text

# %%
# Change response to json.
response.json()
# Out:
# {'rates': {'btc': {'name': 'Bitcoin',
#    'unit': 'BTC',
#    'value': 1.0,
#    'type': 'crypto'},
#   'eth': {'name': 'Ether', 'unit': 'ETH', 'value': 14.583, 'type': 'crypto'},
#   'ltc': {'name': 'Litecoin',
#    'unit': 'LTC',
#    'value': 247.572,
#    'type': 'crypto'},
#   'bch': {'name': 'Bitcoin Cash',
#    'unit': 'BCH',
#    'value': 181.8,
#    'type': 'crypto'},
#   'bnb': {'name': 'Binance Coin',
#    'unit': 'BNB',
#    'value': 78.062,
#    'type': 'crypto'},
#   'eos': {'name': 'EOS', 'unit': 'EOS', 'value': 19980.52, 'type': 'crypto'},
#   'xrp': {'name': 'XRP', 'unit': 'XRP', 'value': 62590.731, 'type': 'crypto'},
#   'xlm': {'name': 'Lumens',
#    'unit': 'XLM',
#    'value': 268207.128,
#    'type': 'crypto'},
#   'link': {'name': 'Chainlink',
#    'unit': 'LINK',
#    'value': 3061.383,
#    'type': 'crypto'},
#   'dot': {'name': 'Polkadot',
#    'unit': 'DOT',
#    'value': 3415.044,
#    'type': 'crypto'},
#   'yfi': {'name': 'Yearn.finance',
#    'unit': 'YFI',
#    'value': 3.336,
#    'type': 'crypto'},
#   'usd': {'name': 'US Dollar',
#    'unit': '$',
#    'value': 24602.651,
#    'type': 'fiat'},
#   'aed': {'name': 'United Arab Emirates Dirham',
#    'unit': 'DH',
#    'value': 90364.309,
#    'type': 'fiat'},
#   'ars': {'name': 'Argentine Peso',
#    'unit': '$',
#    'value': 4739053.451,
#    'type': 'fiat'},
#   'aud': {'name': 'Australian Dollar',
#    'unit': 'A$',
#    'value': 35764.874,
#    'type': 'fiat'},
#   'bdt': {'name': 'Bangladeshi Taka',
#    'unit': '৳',
#    'value': 2579701.902,
#    'type': 'fiat'},
#   'bhd': {'name': 'Bahraini Dinar',
#    'unit': 'BD',
#    'value': 9249.957,
#    'type': 'fiat'},
#   'bmd': {'name': 'Bermudian Dollar',
#    'unit': '$',
#    'value': 24602.651,
#    'type': 'fiat'},
#   'brl': {'name': 'Brazil Real',
#    'unit': 'R$',
#    'value': 127107.14,
#    'type': 'fiat'},
#   'cad': {'name': 'Canadian Dollar',
#    'unit': 'CA$',
#    'value': 33150.843,
#    'type': 'fiat'},
#   'chf': {'name': 'Swiss Franc',
#    'unit': 'Fr.',
#    'value': 22756.025,
#    'type': 'fiat'},
#   'clp': {'name': 'Chilean Peso',
#    'unit': 'CLP$',
#    'value': 19420103.202,
#    'type': 'fiat'},
#   'cny': {'name': 'Chinese Yuan',
#    'unit': '¥',
#    'value': 168961.171,
#    'type': 'fiat'},
#   'czk': {'name': 'Czech Koruna',
#    'unit': 'Kč',
#    'value': 545182.462,
#    'type': 'fiat'},
#   'dkk': {'name': 'Danish Krone',
#    'unit': 'kr.',
#    'value': 171288.582,
#    'type': 'fiat'},
#   'eur': {'name': 'Euro', 'unit': '€', 'value': 22957.743, 'type': 'fiat'},
#   'gbp': {'name': 'British Pound Sterling',
#    'unit': '£',
#    'value': 20427.311,
#    'type': 'fiat'},
#   'hkd': {'name': 'Hong Kong Dollar',
#    'unit': 'HK$',
#    'value': 193036.096,
#    'type': 'fiat'},
#   'huf': {'name': 'Hungarian Forint',
#    'unit': 'Ft',
#    'value': 8827431.467,
#    'type': 'fiat'},
#   'idr': {'name': 'Indonesian Rupiah',
#    'unit': 'Rp',
#    'value': 373106716.689,
#    'type': 'fiat'},
#   'ils': {'name': 'Israeli New Shekel',
#    'unit': '₪',
#    'value': 87373.857,
#    'type': 'fiat'},
#   'inr': {'name': 'Indian Rupee',
#    'unit': '₹',
#    'value': 2037447.697,
#    'type': 'fiat'},
#   'jpy': {'name': 'Japanese Yen',
#    'unit': '¥',
#    'value': 3299337.969,
#    'type': 'fiat'},
#   'krw': {'name': 'South Korean Won',
#    'unit': '₩',
#    'value': 31881100.315,
#    'type': 'fiat'},
#   'kwd': {'name': 'Kuwaiti Dinar',
#    'unit': 'KD',
#    'value': 7537.514,
#    'type': 'fiat'},
#   'lkr': {'name': 'Sri Lankan Rupee',
#    'unit': 'Rs',
#    'value': 8994897.56,
#    'type': 'fiat'},
#   'mmk': {'name': 'Burmese Kyat',
#    'unit': 'K',
#    'value': 51680803.589,
#    'type': 'fiat'},
#   'mxn': {'name': 'Mexican Peso',
#    'unit': 'MX$',
#    'value': 451734.21,
#    'type': 'fiat'},
#   'myr': {'name': 'Malaysian Ringgit',
#    'unit': 'RM',
#    'value': 109038.952,
#    'type': 'fiat'},
#   'ngn': {'name': 'Nigerian Naira',
#    'unit': '₦',
#    'value': 11330505.262,
#    'type': 'fiat'},
#   'nok': {'name': 'Norwegian Krone',
#    'unit': 'kr',
#    'value': 253028.432,
#    'type': 'fiat'},
#   'nzd': {'name': 'New Zealand Dollar',
#    'unit': 'NZ$',
#    'value': 39395.758,
#    'type': 'fiat'},
#   'php': {'name': 'Philippine Peso',
#    'unit': '₱',
#    'value': 1361141.809,
#    'type': 'fiat'},
#   'pkr': {'name': 'Pakistani Rupee',
#    'unit': '₨',
#    'value': 6469882.358,
#    'type': 'fiat'},
#   'pln': {'name': 'Polish Zloty',
#    'unit': 'zł',
#    'value': 109465.808,
#    'type': 'fiat'},
#   'rub': {'name': 'Russian Ruble',
#    'unit': '₽',
#    'value': 1821069.711,
#    'type': 'fiat'},
#   'sar': {'name': 'Saudi Riyal',
#    'unit': 'SR',
#    'value': 92203.456,
#    'type': 'fiat'},
#   'sek': {'name': 'Swedish Krona',
#    'unit': 'kr',
#    'value': 257127.234,
#    'type': 'fiat'},
#   'sgd': {'name': 'Singapore Dollar',
#    'unit': 'S$',
#    'value': 32893.745,
#    'type': 'fiat'},
#   'thb': {'name': 'Thai Baht',
#    'unit': '฿',
#    'value': 845404.243,
#    'type': 'fiat'},
#   'try': {'name': 'Turkish Lira',
#    'unit': '₺',
#    'value': 463240.87,
#    'type': 'fiat'},
#   'twd': {'name': 'New Taiwan Dollar',
#    'unit': 'NT$',
#    'value': 747645.065,
#    'type': 'fiat'},
#   'uah': {'name': 'Ukrainian hryvnia',
#    'unit': '₴',
#    'value': 904300.211,
#    'type': 'fiat'},
#   'vef': {'name': 'Venezuelan bolívar fuerte',
#    'unit': 'Bs.F',
#    'value': 2463.463,
#    'type': 'fiat'},
#   'vnd': {'name': 'Vietnamese đồng',
#    'unit': '₫',
#    'value': 584525002.609,
#    'type': 'fiat'},
#   'zar': {'name': 'South African Rand',
#    'unit': 'R',
#    'value': 444125.594,
#    'type': 'fiat'},
#   'xdr': {'name': 'IMF Special Drawing Rights',
#    'unit': 'XDR',
#    'value': 18410.41,
#    'type': 'fiat'},
#   'xag': {'name': 'Silver - Troy Ounce',
#    'unit': 'XAG',
#    'value': 1132.432,
#    'type': 'commodity'},
#   'xau': {'name': 'Gold - Troy Ounce',
#    'unit': 'XAU',
#    'value': 13.352,
#    'type': 'commodity'},
#   'bits': {'name': 'Bits',
#    'unit': 'μBTC',
#    'value': 1000000.0,
#    'type': 'crypto'},
#   'sats': {'name': 'Satoshi',
#    'unit': 'sats',
#    'value': 100000000.0,
#    'type': 'crypto'}}}

# %%
# Get the information again from the API.
r = requests.get(url=URL)

# View the information.
print(type(r.text))
print(r.text)
# Out:
# <class 'str'>
# {"rates":{"btc":{"name":"Bitcoin","unit":"BTC","value":1.0,"type":"crypto"},"eth":{"name":"Ether","unit":"ETH","value":14.581,"type":"crypto"},"ltc":{"name":"Litecoin","unit":"LTC","value":247.564,"type":"crypto"},"bch":{"name":"Bitcoin Cash","unit":"BCH","value":181.795,"type":"crypto"},"bnb":{"name":"Binance Coin","unit":"BNB","value":78.117,"type":"crypto"},"eos":{"name":"EOS","unit":"EOS","value":19961.168,"type":"crypto"},"xrp":{"name":"XRP","unit":"XRP","value":62584.085,"type":"crypto"},"xlm":{"name":"Lumens","unit":"XLM","value":268203.996,"type":"crypto"},"link":{"name":"Chainlink","unit":"LINK","value":3060.724,"type":"crypto"},"dot":{"name":"Polkadot","unit":"DOT","value":3412.822,"type":"crypto"},"yfi":{"name":"Yearn.finance","unit":"YFI","value":3.335,"type":"crypto"},"usd":{"name":"US Dollar","unit":"$","value":24602.838,"type":"fiat"},"aed":{"name":"United Arab Emirates Dirham","unit":"DH","value":90364.994,"type":"fiat"},"ars":{"name":"Argentine Peso","unit":"$","value":4739089.335,"type":"fiat"},"aud":{"name":"Australian Dollar","unit":"A$","value":35765.145,"type":"fiat"},"bdt":{"name":"Bangladeshi Taka","unit":"৳","value":2579721.436,"type":"fiat"},"bhd":{"name":"Bahraini Dinar","unit":"BD","value":9250.027,"type":"fiat"},"bmd":{"name":"Bermudian Dollar","unit":"$","value":24602.838,"type":"fiat"},"brl":{"name":"Brazil Real","unit":"R$","value":127108.102,"type":"fiat"},"cad":{"name":"Canadian Dollar","unit":"CA$","value":33151.094,"type":"fiat"},"chf":{"name":"Swiss Franc","unit":"Fr.","value":22756.198,"type":"fiat"},"clp":{"name":"Chilean Peso","unit":"CLP$","value":19420250.249,"type":"fiat"},"cny":{"name":"Chinese Yuan","unit":"¥","value":168962.45,"type":"fiat"},"czk":{"name":"Czech Koruna","unit":"Kč","value":545186.59,"type":"fiat"},"dkk":{"name":"Danish Krone","unit":"kr.","value":171289.879,"type":"fiat"},"eur":{"name":"Euro","unit":"€","value":22957.916,"type":"fiat"},"gbp":{"name":"British Pound Sterling","unit":"£","value":20427.465,"type":"fiat"},"hkd":{"name":"Hong Kong Dollar","unit":"HK$","value":193037.558,"type":"fiat"},"huf":{"name":"Hungarian Forint","unit":"Ft","value":8827498.308,"type":"fiat"},"idr":{"name":"Indonesian Rupiah","unit":"Rp","value":373109541.819,"type":"fiat"},"ils":{"name":"Israeli New Shekel","unit":"₪","value":87374.519,"type":"fiat"},"inr":{"name":"Indian Rupee","unit":"₹","value":2037463.124,"type":"fiat"},"jpy":{"name":"Japanese Yen","unit":"¥","value":3299362.951,"type":"fiat"},"krw":{"name":"South Korean Won","unit":"₩","value":31881341.716,"type":"fiat"},"kwd":{"name":"Kuwaiti Dinar","unit":"KD","value":7537.571,"type":"fiat"},"lkr":{"name":"Sri Lankan Rupee","unit":"Rs","value":8994965.669,"type":"fiat"},"mmk":{"name":"Burmese Kyat","unit":"K","value":51681194.911,"type":"fiat"},"mxn":{"name":"Mexican Peso","unit":"MX$","value":451737.63,"type":"fiat"},"myr":{"name":"Malaysian Ringgit","unit":"RM","value":109039.778,"type":"fiat"},"ngn":{"name":"Nigerian Naira","unit":"₦","value":11330591.055,"type":"fiat"},"nok":{"name":"Norwegian Krone","unit":"kr","value":253030.348,"type":"fiat"},"nzd":{"name":"New Zealand Dollar","unit":"NZ$","value":39396.057,"type":"fiat"},"php":{"name":"Philippine Peso","unit":"₱","value":1361152.115,"type":"fiat"},"pkr":{"name":"Pakistani Rupee","unit":"₨","value":6469931.347,"type":"fiat"},"pln":{"name":"Polish Zloty","unit":"zł","value":109466.637,"type":"fiat"},"rub":{"name":"Russian Ruble","unit":"₽","value":1821083.5,"type":"fiat"},"sar":{"name":"Saudi Riyal","unit":"SR","value":92204.154,"type":"fiat"},"sek":{"name":"Swedish Krona","unit":"kr","value":257129.181,"type":"fiat"},"sgd":{"name":"Singapore Dollar","unit":"S$","value":32893.994,"type":"fiat"},"thb":{"name":"Thai Baht","unit":"฿","value":845410.644,"type":"fiat"},"try":{"name":"Turkish Lira","unit":"₺","value":463244.378,"type":"fiat"},"twd":{"name":"New Taiwan Dollar","unit":"NT$","value":747650.726,"type":"fiat"},"uah":{"name":"Ukrainian hryvnia","unit":"₴","value":9 ...

# %%
# Parse JSON data with loads().
content = json.loads(r.text)

# View the content.
print(type(content))
print(content['rates'])
# Out:
# <class 'dict'>
# {'btc': {'name': 'Bitcoin', 'unit': 'BTC', 'value': 1.0, 'type': 'crypto'}, 'eth': {'name': 'Ether', 'unit': 'ETH', 'value': 14.581, 'type': 'crypto'}, 'ltc': {'name': 'Litecoin', 'unit': 'LTC', 'value': 247.564, 'type': 'crypto'}, 'bch': {'name': 'Bitcoin Cash', 'unit': 'BCH', 'value': 181.795, 'type': 'crypto'}, 'bnb': {'name': 'Binance Coin', 'unit': 'BNB', 'value': 78.117, 'type': 'crypto'}, 'eos': {'name': 'EOS', 'unit': 'EOS', 'value': 19961.168, 'type': 'crypto'}, 'xrp': {'name': 'XRP', 'unit': 'XRP', 'value': 62584.085, 'type': 'crypto'}, 'xlm': {'name': 'Lumens', 'unit': 'XLM', 'value': 268203.996, 'type': 'crypto'}, 'link': {'name': 'Chainlink', 'unit': 'LINK', 'value': 3060.724, 'type': 'crypto'}, 'dot': {'name': 'Polkadot', 'unit': 'DOT', 'value': 3412.822, 'type': 'crypto'}, 'yfi': {'name': 'Yearn.finance', 'unit': 'YFI', 'value': 3.335, 'type': 'crypto'}, 'usd': {'name': 'US Dollar', 'unit': '$', 'value': 24602.838, 'type': 'fiat'}, 'aed': {'name': 'United Arab Emirates Dirham', 'unit': 'DH', 'value': 90364.994, 'type': 'fiat'}, 'ars': {'name': 'Argentine Peso', 'unit': '$', 'value': 4739089.335, 'type': 'fiat'}, 'aud': {'name': 'Australian Dollar', 'unit': 'A$', 'value': 35765.145, 'type': 'fiat'}, 'bdt': {'name': 'Bangladeshi Taka', 'unit': '৳', 'value': 2579721.436, 'type': 'fiat'}, 'bhd': {'name': 'Bahraini Dinar', 'unit': 'BD', 'value': 9250.027, 'type': 'fiat'}, 'bmd': {'name': 'Bermudian Dollar', 'unit': '$', 'value': 24602.838, 'type': 'fiat'}, 'brl': {'name': 'Brazil Real', 'unit': 'R$', 'value': 127108.102, 'type': 'fiat'}, 'cad': {'name': 'Canadian Dollar', 'unit': 'CA$', 'value': 33151.094, 'type': 'fiat'}, 'chf': {'name': 'Swiss Franc', 'unit': 'Fr.', 'value': 22756.198, 'type': 'fiat'}, 'clp': {'name': 'Chilean Peso', 'unit': 'CLP$', 'value': 19420250.249, 'type': 'fiat'}, 'cny': {'name': 'Chinese Yuan', 'unit': '¥', 'value': 168962.45, 'type': 'fiat'}, 'czk': {'name': 'Czech Koruna', 'unit': 'Kč', 'value': 545186.59, 'type': 'fiat'}, 'dkk': {'name': 'Danish Krone', 'unit': 'kr.', 'value': 171289.879, 'type': 'fiat'}, 'eur': {'name': 'Euro', 'unit': '€', 'value': 22957.916, 'type': 'fiat'}, 'gbp': {'name': 'British Pound Sterling', 'unit': '£', 'value': 20427.465, 'type': 'fiat'}, 'hkd': {'name': 'Hong Kong Dollar', 'unit': 'HK$', 'value': 193037.558, 'type': 'fiat'}, 'huf': {'name': 'Hungarian Forint', 'unit': 'Ft', 'value': 8827498.308, 'type': 'fiat'}, 'idr': {'name': 'Indonesian Rupiah', 'unit': 'Rp', 'value': 373109541.819, 'type': 'fiat'}, 'ils': {'name': 'Israeli New Shekel', 'unit': '₪', 'value': 87374.519, 'type': 'fiat'}, 'inr': {'name': 'Indian Rupee', 'unit': '₹', 'value': 2037463.124, 'type': 'fiat'}, 'jpy': {'name': 'Japanese Yen', 'unit': '¥', 'value': 3299362.951, 'type': 'fiat'}, 'krw': {'name': 'South Korean Won', 'unit': '₩', 'value': 31881341.716, 'type': 'fiat'}, 'kwd': {'name': 'Kuwaiti Dinar', 'unit': 'KD', 'value': 7537.571, 'type': 'fiat'}, 'lkr': {'name': 'Sri Lankan Rupee', 'unit': 'Rs', 'value': 8994965.669, 'type': 'fiat'}, 'mmk': {'name': 'Burmese Kyat', 'unit': 'K', 'value': 51681194.911, 'type': 'fiat'}, 'mxn': {'name': 'Mexican Peso', 'unit': 'MX$', 'value': 451737.63, 'type': 'fiat'}, 'myr': {'name': 'Malaysian Ringgit', 'unit': 'RM', 'value': 109039.778, 'type': 'fiat'}, 'ngn': {'name': 'Nigerian Naira', 'unit': '₦', 'value': 11330591.055, 'type': 'fiat'}, 'nok': {'name': 'Norwegian Krone', 'unit': 'kr', 'value': 253030.348, 'type': 'fiat'}, 'nzd': {'name': 'New Zealand Dollar', 'unit': 'NZ$', 'value': 39396.057, 'type': 'fiat'}, 'php': {'name': 'Philippine Peso', 'unit': '₱', 'value': 1361152.115, 'type': 'fiat'}, 'pkr': {'name': 'Pakistani Rupee', 'unit': '₨', 'value': 6469931.347, 'type': 'fiat'}, 'pln': {'name': 'Polish Zloty', 'unit': 'zł', 'value': 109466.637, 'type': 'fiat'}, 'rub': {'name': 'Russian Ruble', 'unit': '₽', 'value': 1821083.5, 'type': 'fiat'}, 'sar': {'name': 'Saudi Riyal', 'unit': 'SR', 'value': 92204.154, 'type': 'fiat'}, 'sek': {'name': 'Swe ...

# %%
# Formatting JSON.
print(json.dumps(content, indent=4))
# Out:
# {
#     "rates": {
#         "btc": {
#             "name": "Bitcoin",
#             "unit": "BTC",
#             "value": 1.0,
#             "type": "crypto"
#         },
#         "eth": {
#             "name": "Ether",
#             "unit": "ETH",
#             "value": 14.581,
#             "type": "crypto"
#         },
#         "ltc": {
#             "name": "Litecoin",
#             "unit": "LTC",
#             "value": 247.564,
#             "type": "crypto"
#         },
#         "bch": {
#             "name": "Bitcoin Cash",
#             "unit": "BCH",
#             "value": 181.795,
#             "type": "crypto"
#         },
#         "bnb": {
#             "name": "Binance Coin",
#             "unit": "BNB",
#             "value": 78.117,
#             "type": "crypto"
#         },
#         "eos": {
#             "name": "EOS",
#             "unit": "EOS",
#             "value": 19961.168,
#             "type": "crypto"
#         },
#         "xrp": {
#             "name": "XRP",
#             "unit": "XRP",
#             "value": 62584.085,
#             "type": "crypto"
#         },
#         "xlm": {
#             "name": "Lumens",
#             "unit": "XLM",
#             "value": 268203.996,
#             "type": "crypto"
#         },
#         "link": {
#             "name": "Chainlink",
#             "unit": "LINK",
#             "value": 3060.724,
#             "type": "crypto"
#         },
#         "dot": {
#             "name": "Polkadot",
#             "unit": "DOT",
#             "value": 3412.822,
#             "type": "crypto"
#         },
#         "yfi": {
#             "name": "Yearn.finance",
#             "unit": "YFI",
#             "value": 3.335,
#             "type": "crypto"
#         },
#         "usd": {
#             "name": "US Dollar",
#             "unit": "$",
#             "value": 24602.838,
#             "type": "fiat"
#         },
#         "aed": {
#             "name": "United Arab Emirates Dirham",
#             "unit": "DH",
#             "value": 90364.994,
#             "type": "fiat"
#         },
#         "ars": {
#             "name": "Argentine Peso",
#             "unit": "$",
#             "value": 4739089.335,
#             "type": "fiat"
#         },
#         "aud": {
#             "name": "Australian Dollar",
#             "unit": "A$",
#             "value": 35765.145,
#             "type": "fiat"
#         },
#         "bdt": {
#             "name": "Bangladeshi Taka",
#             "unit": "\u09f3",
#             "value": 2579721.436,
#             "type": "fiat"
#         },
#         "bhd": {
#             "name": "Bahraini Dinar",
#             "unit": "BD",
#             "value": 9250.027,
#             "type": "fiat"
#         },
#         "bmd": {
#             "name": "Bermudian Dollar",
#             "unit": "$",
#             "value": 24602.838,
#             "type": "fiat"
#         },
#         "brl": {
#             "name": "Brazil Real",
#             "unit": "R$",
#             "value": 127108.102,
#             "type": "fiat"
#         },
#         "cad": {
#             "name": "Canadian Dollar",
#             "unit": "CA$",
#             "value": 33151.094,
#             "type": "fiat"
#         },
#         "chf": {
#             "name": "Swiss Franc",
#             "unit": "Fr.",
#             "value": 22756.198,
#             "type": "fiat"
#         },
#         "clp": {
#             "name": "Chilean Peso",
#             "unit": "CLP$",
#             "value": 19420250.249,
#             "type": "fiat"
#         },
#         "cny": {
#             "name": "Chinese Yuan",
#             "unit": "\u00a5",
#             "value": 168962.45,
#             "type": "fiat"
#         },
#         "czk": {
#             "name": "Czech Koruna",
#             "unit": "K\u010d",
#             "value": 545186.59,
#             "type": "fiat"
#         },
#         "dkk": {
#             "name": "Danish Krone",
#             "unit": "kr.",
#             "value": 171289.879,
#             "type": "fiat"
#         },
#         "eur": {
#             "name": "Euro",
#             "unit": "\u20ac",
#             "value": 22957.916,
#             "type": "fiat"
#         },
#         "gbp": {
#             "name": "British Pound Sterling",
#             "unit": "\u00a3",
#             "value": 20427.465,
#             "type": "fiat"
#         },
#         "hkd": {
#             "name": "Hong Kong Dollar",
#             "unit": "HK$",
#             "value": 193037.558,
#             "type": "fiat"
#         },
#         "huf": {
#             "name": "Hungarian Forint",
#             "unit": "Ft",
#             "value": 8827498.308,
#             "type": "fiat"
#         },
#         "idr": {
#             "name": "Indonesian Rupiah",
#             "unit": "Rp",
#             "value": 373109541.819,
#             "type": "fiat"
#         },
#         "ils": {
#             "name": "Israeli New Shekel",
#             "unit": "\u20aa",
#             "value": 87374.519,
#             "type": "fiat"
#         },
#         "inr": {
#             "name": "Indian Rupee",
#             "unit": "\u20b9",
#             "value": 2037463.124,
#             "type": "fiat"
#         },
#         "jpy": {
#             "name": "Japanese Yen",
#             "unit": "\u00a5",
#             "value": 3299362.951,
#             "type": "fiat"
#         },
#         "krw": {
#             "name": "South Korean Won",
#             "unit": "\u20a9",
#             "value": 31881341.716,
#             "type": "fiat"
#         },
#         "kwd": {
#             "name": "Kuwaiti Dinar",
#             "unit": "KD",
#             "value": 7537.571,
#             "type": "fiat"
#         },
#         "lkr": {
#             "name": "Sri Lankan Rupee",
#             "unit": "Rs",
#             "value": 8994965.669,
#             "type": "fiat"
#         },
#         "mmk": {
#             "name": "Burmese Kyat",
#             "unit": "K",
#             "value": 51681194.911,
#             "type": "fiat"
#         },
#         "mxn": {
#             "name": "Mexican Peso",
#             "unit": "MX$",
#             "value": 451737.63,
#             "type": "fiat"
#         },
#         "myr": {
#             "name": "Malaysian Ringgit",
#             "unit": "RM",
#             "value": 109039.778,
#             "type": "fiat"
#         },
#         "ngn": {
#             "name": "Nigerian Naira",
#             "unit": "\u20a6",
#             "value": 11330591.055,
#             "type": "fiat"
#         },
#         "nok": {
#             "name": "Norwegian Krone",
#             "unit": "kr",
#             "value": 253030.348,
#             "type": "fiat"
#         },
#         "nzd": {
#             "name": "New Zealand Dollar",
#             "unit": "NZ$",
#             "value": 39396.057,
#             "type": "fiat"
#         },
#         "php": {
#             "name": "Philippine Peso",
#             "unit": "\u20b1",
#             "value": 1361152.115,
#             "type": "fiat"
#         },
#         "pkr": {
#             "name": "Pakistani Rupee",
#             "unit": "\u20a8",
#             "value": 6469931.347,
#             "type": "fiat"
#         },
#         "pln": {
#             "name": "Polish Zloty",
#             "unit": "z\u0142",
#             "value": 109466.637,
#             "type": "fiat"
#         },
#         "rub": {
#             "name": "Russian Ruble",
#             "unit": "\u20bd",
#             "value": 1821083.5,
#             "type": "fiat"
#         },
#         "sar": {
#             "name": "Saudi Riyal",
#             "unit": "SR",
#             "value": 92204.154,
#             "type": "fiat"
#         },
#         "sek": {
#             "name": "Swedish Krona",
#             "unit": "kr",
#             "value": 257129.181,
#             "type": "fiat"
#         },
#         "sgd": {
#             "name": "Singapore Dollar",
#             "unit": "S$",
#             "value": 32893.994,
#             "type": "fiat"
#         },
#         "thb": {
#             "name": "Thai Baht",
#             "unit": "\u0e3f",
#             "value": 845410.644,
#             "type": "fiat"
#         },
#         "try": {
#             "name": "Turkish Lira",
#             "unit": "\u20ba",
#             "value": 463244.378,
#             "type": "fiat"
#         },
#         "twd": {
#             "name": "New Taiwan Dollar",
#             "unit": "NT$",
#             "value": 747650.726,
#             "type": "fiat"
#         },
#         "uah": {
#             "name": "Ukrainian hryvnia",
#             "unit": "\u20b4",
#             "value": 904307.058,
#             "type": "fiat"
#         },
#         "vef": {
#             "name": "Venezuelan bol\u00edvar fuerte",
#             "unit": "Bs.F",
#             "value": 2463.482,
#             "type": "fiat"
#         },
#         "vnd": {
#             "name": "Vietnamese \u0111\u1ed3ng",
#             "unit": "\u20ab",
#             "value": 584529428.578,
#             "type": "fiat"
#         },
#         "zar": {
#             "name": "South African Rand",
#             "unit": "R",
#             "value": 444128.957,
#             "type": "fiat"
#         },
#         "xdr": {
#             "name": "IMF Special Drawing Rights",
#             "unit": "XDR",
#             "value": 18410.549,
#             "type": "fiat"
#         },
#         "xag": {
#             "name": "Silver - Troy Ounce",
#             "unit": "XAG",
#             "value": 1132.441,
#             "type": "commodity"
#         },
#         "xau": {
#             "name": "Gold - Troy Ounce",
#             "unit": "XAU",
#             "value": 13.352,
#             "type": "commodity"
#         },
#         "bits": {
#             "name": "Bits",
#             "unit": "\u03bcBTC",
#             "value": 1000000.0,
#             "type": "crypto"
#         },
#         "sats": {
#             "name": "Satoshi",
#             "unit": "sats",
#             "value": 100000000.0,
#             "type": "crypto"
#         }
#     }
# }

# %%
# Formatting JSON.
print(json.dumps(content, indent=4, separators=('. ', ' = ')))
# Out:
# {
#     "rates" = {
#         "btc" = {
#             "name" = "Bitcoin".
#             "unit" = "BTC".
#             "value" = 1.0.
#             "type" = "crypto"
#         }.
#         "eth" = {
#             "name" = "Ether".
#             "unit" = "ETH".
#             "value" = 14.581.
#             "type" = "crypto"
#         }.
#         "ltc" = {
#             "name" = "Litecoin".
#             "unit" = "LTC".
#             "value" = 247.564.
#             "type" = "crypto"
#         }.
#         "bch" = {
#             "name" = "Bitcoin Cash".
#             "unit" = "BCH".
#             "value" = 181.795.
#             "type" = "crypto"
#         }.
#         "bnb" = {
#             "name" = "Binance Coin".
#             "unit" = "BNB".
#             "value" = 78.117.
#             "type" = "crypto"
#         }.
#         "eos" = {
#             "name" = "EOS".
#             "unit" = "EOS".
#             "value" = 19961.168.
#             "type" = "crypto"
#         }.
#         "xrp" = {
#             "name" = "XRP".
#             "unit" = "XRP".
#             "value" = 62584.085.
#             "type" = "crypto"
#         }.
#         "xlm" = {
#             "name" = "Lumens".
#             "unit" = "XLM".
#             "value" = 268203.996.
#             "type" = "crypto"
#         }.
#         "link" = {
#             "name" = "Chainlink".
#             "unit" = "LINK".
#             "value" = 3060.724.
#             "type" = "crypto"
#         }.
#         "dot" = {
#             "name" = "Polkadot".
#             "unit" = "DOT".
#             "value" = 3412.822.
#             "type" = "crypto"
#         }.
#         "yfi" = {
#             "name" = "Yearn.finance".
#             "unit" = "YFI".
#             "value" = 3.335.
#             "type" = "crypto"
#         }.
#         "usd" = {
#             "name" = "US Dollar".
#             "unit" = "$".
#             "value" = 24602.838.
#             "type" = "fiat"
#         }.
#         "aed" = {
#             "name" = "United Arab Emirates Dirham".
#             "unit" = "DH".
#             "value" = 90364.994.
#             "type" = "fiat"
#         }.
#         "ars" = {
#             "name" = "Argentine Peso".
#             "unit" = "$".
#             "value" = 4739089.335.
#             "type" = "fiat"
#         }.
#         "aud" = {
#             "name" = "Australian Dollar".
#             "unit" = "A$".
#             "value" = 35765.145.
#             "type" = "fiat"
#         }.
#         "bdt" = {
#             "name" = "Bangladeshi Taka".
#             "unit" = "\u09f3".
#             "value" = 2579721.436.
#             "type" = "fiat"
#         }.
#         "bhd" = {
#             "name" = "Bahraini Dinar".
#             "unit" = "BD".
#             "value" = 9250.027.
#             "type" = "fiat"
#         }.
#         "bmd" = {
#             "name" = "Bermudian Dollar".
#             "unit" = "$".
#             "value" = 24602.838.
#             "type" = "fiat"
#         }.
#         "brl" = {
#             "name" = "Brazil Real".
#             "unit" = "R$".
#             "value" = 127108.102.
#             "type" = "fiat"
#         }.
#         "cad" = {
#             "name" = "Canadian Dollar".
#             "unit" = "CA$".
#             "value" = 33151.094.
#             "type" = "fiat"
#         }.
#         "chf" = {
#             "name" = "Swiss Franc".
#             "unit" = "Fr.".
#             "value" = 22756.198.
#             "type" = "fiat"
#         }.
#         "clp" = {
#             "name" = "Chilean Peso".
#             "unit" = "CLP$".
#             "value" = 19420250.249.
#             "type" = "fiat"
#         }.
#         "cny" = {
#             "name" = "Chinese Yuan".
#             "unit" = "\u00a5".
#             "value" = 168962.45.
#             "type" = "fiat"
#         }.
#         "czk" = {
#             "name" = "Czech Koruna".
#             "unit" = "K\u010d".
#             "value" = 545186.59.
#             "type" = "fiat"
#         }.
#         "dkk" = {
#             "name" = "Danish Krone".
#             "unit" = "kr.".
#             "value" = 171289.879.
#             "type" = "fiat"
#         }.
#         "eur" = {
#             "name" = "Euro".
#             "unit" = "\u20ac".
#             "value" = 22957.916.
#             "type" = "fiat"
#         }.
#         "gbp" = {
#             "name" = "British Pound Sterling".
#             "unit" = "\u00a3".
#             "value" = 20427.465.
#             "type" = "fiat"
#         }.
#         "hkd" = {
#             "name" = "Hong Kong Dollar".
#             "unit" = "HK$".
#             "value" = 193037.558.
#             "type" = "fiat"
#         }.
#         "huf" = {
#             "name" = "Hungarian Forint".
#             "unit" = "Ft".
#             "value" = 8827498.308.
#             "type" = "fiat"
#         }.
#         "idr" = {
#             "name" = "Indonesian Rupiah".
#             "unit" = "Rp".
#             "value" = 373109541.819.
#             "type" = "fiat"
#         }.
#         "ils" = {
#             "name" = "Israeli New Shekel".
#             "unit" = "\u20aa".
#             "value" = 87374.519.
#             "type" = "fiat"
#         }.
#         "inr" = {
#             "name" = "Indian Rupee".
#             "unit" = "\u20b9".
#             "value" = 2037463.124.
#             "type" = "fiat"
#         }.
#         "jpy" = {
#             "name" = "Japanese Yen".
#             "unit" = "\u00a5".
#             "value" = 3299362.951.
#             "type" = "fiat"
#         }.
#         "krw" = {
#             "name" = "South Korean Won".
#             "unit" = "\u20a9".
#             "value" = 31881341.716.
#             "type" = "fiat"
#         }.
#         "kwd" = {
#             "name" = "Kuwaiti Dinar".
#             "unit" = "KD".
#             "value" = 7537.571.
#             "type" = "fiat"
#         }.
#         "lkr" = {
#             "name" = "Sri Lankan Rupee".
#             "unit" = "Rs".
#             "value" = 8994965.669.
#             "type" = "fiat"
#         }.
#         "mmk" = {
#             "name" = "Burmese Kyat".
#             "unit" = "K".
#             "value" = 51681194.911.
#             "type" = "fiat"
#         }.
#         "mxn" = {
#             "name" = "Mexican Peso".
#             "unit" = "MX$".
#             "value" = 451737.63.
#             "type" = "fiat"
#         }.
#         "myr" = {
#             "name" = "Malaysian Ringgit".
#             "unit" = "RM".
#             "value" = 109039.778.
#             "type" = "fiat"
#         }.
#         "ngn" = {
#             "name" = "Nigerian Naira".
#             "unit" = "\u20a6".
#             "value" = 11330591.055.
#             "type" = "fiat"
#         }.
#         "nok" = {
#             "name" = "Norwegian Krone".
#             "unit" = "kr".
#             "value" = 253030.348.
#             "type" = "fiat"
#         }.
#         "nzd" = {
#             "name" = "New Zealand Dollar".
#             "unit" = "NZ$".
#             "value" = 39396.057.
#             "type" = "fiat"
#         }.
#         "php" = {
#             "name" = "Philippine Peso".
#             "unit" = "\u20b1".
#             "value" = 1361152.115.
#             "type" = "fiat"
#         }.
#         "pkr" = {
#             "name" = "Pakistani Rupee".
#             "unit" = "\u20a8".
#             "value" = 6469931.347.
#             "type" = "fiat"
#         }.
#         "pln" = {
#             "name" = "Polish Zloty".
#             "unit" = "z\u0142".
#             "value" = 109466.637.
#             "type" = "fiat"
#         }.
#         "rub" = {
#             "name" = "Russian Ruble".
#             "unit" = "\u20bd".
#             "value" = 1821083.5.
#             "type" = "fiat"
#         }.
#         "sar" = {
#             "name" = "Saudi Riyal".
#             "unit" = "SR".
#             "value" = 92204.154.
#             "type" = "fiat"
#         }.
#         "sek" = {
#             "name" = "Swedish Krona".
#             "unit" = "kr".
#             "value" = 257129.181.
#             "type" = "fiat"
#         }.
#         "sgd" = {
#             "name" = "Singapore Dollar".
#             "unit" = "S$".
#             "value" = 32893.994.
#             "type" = "fiat"
#         }.
#         "thb" = {
#             "name" = "Thai Baht".
#             "unit" = "\u0e3f".
#             "value" = 845410.644.
#             "type" = "fiat"
#         }.
#         "try" = {
#             "name" = "Turkish Lira".
#             "unit" = "\u20ba".
#             "value" = 463244.378.
#             "type" = "fiat"
#         }.
#         "twd" = {
#             "name" = "New Taiwan Dollar".
#             "unit" = "NT$".
#             "value" = 747650.726.
#             "type" = "fiat"
#         }.
#         "uah" = {
#             "name" = "Ukrainian hryvnia".
#             "unit" = "\u20b4".
#             "value" = 904307.058.
#             "type" = "fiat"
#         }.
#         "vef" = {
#             "name" = "Venezuelan bol\u00edvar fuerte".
#             "unit" = "Bs.F".
#             "value" = 2463.482.
#             "type" = "fiat"
#         }.
#         "vnd" = {
#             "name" = "Vietnamese \u0111\u1ed3ng".
#             "unit" = "\u20ab".
#             "value" = 584529428.578.
#             "type" = "fiat"
#         }.
#         "zar" = {
#             "name" = "South African Rand".
#             "unit" = "R".
#             "value" = 444128.957.
#             "type" = "fiat"
#         }.
#         "xdr" = {
#             "name" = "IMF Special Drawing Rights".
#             "unit" = "XDR".
#             "value" = 18410.549.
#             "type" = "fiat"
#         }.
#         "xag" = {
#             "name" = "Silver - Troy Ounce".
#             "unit" = "XAG".
#             "value" = 1132.441.
#             "type" = "commodity"
#         }.
#         "xau" = {
#             "name" = "Gold - Troy Ounce".
#             "unit" = "XAU".
#             "value" = 13.352.
#             "type" = "commodity"
#         }.
#         "bits" = {
#             "name" = "Bits".
#             "unit" = "\u03bcBTC".
#             "value" = 1000000.0.
#             "type" = "crypto"
#         }.
#         "sats" = {
#             "name" = "Satoshi".
#             "unit" = "sats".
#             "value" = 100000000.0.
#             "type" = "crypto"
#         }
#     }
# }
